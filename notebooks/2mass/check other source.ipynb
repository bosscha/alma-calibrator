# %%
primary = ['J0541-0211', 'J1733-3722', 'J1610-3958', 'J1743-0350', 'J2253+1608', 
           'J1851+0035', 'J0541-0541', 'J0601-7036', 'J1130-1449', 'J1305-4928', 
           'J0336+3218', 'J0006-0623', 'J1717-3342', 'J1833-210B', 'J0237+2848', 
           'J0750+1231', 'J1751+0939', 'J0948+0022', 'J1107-4449', 'J1256-0547', 
           'J1830+0619', 'J1225+1253']

interesting_non_primary = ['J2035+1056', 'J0811-4929', 'J0040-3243', 'J2056-5820', 'J1315-5334', 
'J0340-2119', 'J2158-1501', 'J1038+0512', 'J0531-4827', 'J1007-0207', 
'J2040-5735', 'J0956+2515', 'J1332+0200', 'J0303-6211', 'J0930+0034', 
'J1603-4904', 'J2207-5346', 'J0830+2410', 'J1208-7809', 'J0914+0245', 
'J1319-0049', 'J1232-0224', 'J0516-6207', 'J1351-2912', 'J1103-3251', 
'J1126-3828', 'J2230-4416', 'J1150-0023', 'J1222+0413', 'J0425-5331', 
'J1147-6753', 'J1047-6217', 'J2359-3133', 'J1331+3030', 'J0431+2037', 
'J0431+1731', 'J1410+0203',  'J0501-0159']


secondary = ['J0747-3310', 'J1516+1932', 'J0438+3004', 'J2134-0153', 'J2226+0052', 
           'J0426+2327', 'J1626-2951', 'J1058-8003']

# %%
for i in interesting_non_primary:
    for j in primary:
        if i == j:
            print(i)

# %%
for i in interesting_non_primary:
    for j in secondary:
        if i == j:
            print(i)

# %%
for i in primary:
    print("[["+i+"]]\n")
# Out:
# [[J0541-0211]]
#
# [[J1733-3722]]
#
# [[J1610-3958]]
#
# [[J1743-0350]]
#
# [[J2253+1608]]
#
# [[J1851+0035]]
#
# [[J0541-0541]]
#
# [[J0601-7036]]
#
# [[J1130-1449]]
#
# [[J1305-4928]]
#
# [[J0336+3218]]
#
# [[J0006-0623]]
#
# [[J1717-3342]]
#
# [[J1833-210B]]
#
# [[J0237+2848]]
#
# [[J0750+1231]]
#
# [[J1751+0939]]
#
# [[J0948+0022]]
#
# [[J1107-4449]]
#
# [[J1256-0547]]
#
# [[J1830+0619]]
#
# [[J1225+1253]]

# %%
for i in secondary:
    print("[["+i+"]]\n")
# Out:
# [[J0747-3310]]
#
# [[J1516+1932]]
#
# [[J0438+3004]]
#
# [[J2134-0153]]
#
# [[J2226+0052]]
#
# [[J0426+2327]]
#
# [[J1626-2951]]
#
# [[J1058-8003]]

# %%
for i in interesting_non_primary:
    print("[["+i+"]]\n")
# Out:
# [[J2035+1056]]
#
# [[J0811-4929]]
#
# [[J0040-3243]]
#
# [[J2056-5820]]
#
# [[J1315-5334]]
#
# [[J0340-2119]]
#
# [[J2158-1501]]
#
# [[J1038+0512]]
#
# [[J0531-4827]]
#
# [[J1007-0207]]
#
# [[J2040-5735]]
#
# [[J0956+2515]]
#
# [[J1332+0200]]
#
# [[J0303-6211]]
#
# [[J0930+0034]]
#
# [[J1603-4904]]
#
# [[J2207-5346]]
#
# [[J0830+2410]]
#
# [[J1208-7809]]
#
# [[J0914+0245]]
#
# [[J1319-0049]]
#
# [[J1232-0224]]
#
# [[J0516-6207]]
#
# [[J1351-2912]]
#
# [[J1103-3251]]
#
# [[J1126-3828]]
#
# [[J2230-4416]]
#
# [[J1150-0023]]
#
# [[J1222+0413]]
#
# [[J0425-5331]]
#
# [[J1147-6753]]
#
# [[J1047-6217]]
#
# [[J2359-3133]]
#
# [[J1331+3030]]
#
# [[J0431+2037]]
#
# [[J0431+1731]]
#
# [[J1410+0203]]
#
# [[J0501-0159]]
