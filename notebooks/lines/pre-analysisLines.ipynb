# %%
## run the flagging and analysis of the lines.

import sys
sys.path.append("../../src/lines")

import lineTools as lt

al = lt.analysisLines("/home/stephane/Science/RadioGalaxy/ALMA/absorptions/analysis/a/lineAll.db")
al.clearFlags()
# Out:
# 0

# %%
al.flagLines(edgeFlag = True, telluricFlag= True, duplicateFlag = True)

print("Flagging done ..")
# Out:
# ## View not yet created...
# ## EDGE - Flagged line 15
# ## EDGE - Flagged line 21
# ## EDGE - Flagged line 28
# ## EDGE - Flagged line 31
# ## EDGE - Flagged line 32
# ## EDGE - Flagged line 33
# ## EDGE - Flagged line 35
# ## EDGE - Flagged line 41
# ## EDGE - Flagged line 54
# ## EDGE - Flagged line 60
# ## EDGE - Flagged line 67
# ## EDGE - Flagged line 70
# ## EDGE - Flagged line 71
# ## EDGE - Flagged line 72
# ## EDGE - Flagged line 74
# ## EDGE - Flagged line 80
# ## EDGE - Flagged line 83
# ## EDGE - Flagged line 87
# ## EDGE - Flagged line 88
# ## EDGE - Flagged line 91
# ## EDGE - Flagged line 97
# ## EDGE - Flagged line 101
# ## EDGE - Flagged line 102
# ## EDGE - Flagged line 106
# ## EDGE - Flagged line 116
# ## EDGE - Flagged line 118
# ## EDGE - Flagged line 119
# ## EDGE - Flagged line 121
# ## EDGE - Flagged line 126
# ## EDGE - Flagged line 134
# ## EDGE - Flagged line 135
# ## EDGE - Flagged line 139
# ## EDGE - Flagged line 149
# ## EDGE - Flagged line 151
# ...
