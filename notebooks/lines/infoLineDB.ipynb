# %%
import sys
sys.path.append("../../src/lines")

import lineTools as lt

# %%
al = lt.analysisLines("/home/stephane/Science/RadioGalaxy/ALMA/absorptions/analysis/a/lineAll.db")
res = al.getInfoDB(verbose = True)
# Out:
# ## Sources: 133
# ##
# ## 3C279  J1256-057  J1256-0547  3c279   : 252 lines
# ## Coordinates (J2000): 194.046527 -5.789312
# ## Galactic Coordinates (l,b): (305.104321 , 57.062407)
# ## Redshift:
# [0.5362 0.532  0.395 ]
# ##
# ## Number of MS: 79
#
# ## B0327-241   : 0 lines
# ## Coordinates (J2000): 52.475315 -23.952437
# ## Galactic Coordinates (l,b): (216.888473 , -54.259327)
# ## Redshift:
# [0.895   nan   nan   nan]
# ##
# ## Number of MS: 8
#
# ## Callisto   : 87 lines
# ## Coordinates (J2000): 73.597382 21.753097
# ## Galactic Coordinates (l,b): (179.405065 , -13.595230)
# ## No redshift
#
# ## Ceres   : 94 lines
# ## Coordinates (J2000): 93.816281 22.399326
# ## Galactic Coordinates (l,b): (188.990486 , 2.546137)
# ## No redshift
#
# ## J0006-0623   : 0 lines
# ## Coordinates (J2000): 1.557888 -6.393149
# ## Galactic Coordinates (l,b): (93.505457 , -66.646559)
# ## Redshift:
# [0.346676]
# ##
# ## Number of MS: 4
#
# ## J0010+1058   : 0 lines
# ## Coordinates (J2000): 2.629191 10.974862
# ## Galactic Coordinates (l,b): (106.979407 , -50.625059)
# ## Redshift:
# [0.089338]
# ##
# ## Number of MS: 1
#
# ## J0010+1724   : 0 lines
# ## Coordinates (J2000): 2.641628 17.405211
# ## Galactic Coordinates (l,b): (109.232961 , -44.376672)
# ## Redshift:
# [1.601]
# ##
# ## Number of MS: 1
#
# ## J0057-0024   : 2 lines
# ## Coordinates (J2000): 14.320843 -0.409216
# ## Galactic Coordinates (l,b): (126.179320 , -63.244102)
# ## Redshift:
# [2.752134]
# ##
# ## Number of MS: 1
#
# ## J0108+015  J0108+0135   : 5 lines
# ## Coordinates (J2000): 17.161546 1.583422
# ## Galactic Coordinates (l,b): (131.827034 , -60.990778)
# ## Redshift:
# [2.099]
# ##
# ## Number of MS: 8
#
# ## J0113+0222   : 0 lines
# ## Coordinates (J2000): 18.429771 2.371477
# ## Galactic Coordinates (l,b): (134.121572 , -60.015311)
# ## Redshift:
# [0.047   nan   nan   nan]
# ##
# ## Number of MS: 2
#
# ## J0121+1149   : 16 lines
# ## Coordinates (J2000): 20.423313 11.830670
# ## Galactic Coordinates (l,b): (134.581633 , -50.355462)
# ## Redshift:
# [0.57]
# ##
# ## Number of MS: 7
#
# ## J0132-169   : 26 lines
# ## Coordinates (J2000): 23.181198 -16.913478
# ## Galactic Coordinates (l,b): (168.124134 , -76.017694)
# ## Redshift:
# [1.02  nan]
# ##
# ## Number of MS: 4
#
# ## J0137+3309   : 0 lines
# ## Coordinates (J2000): 24.422081 33.159759
# ## Galactic Coordinates (l,b): (133.962566 , -28.719406)
# ## Redshift:
# [0.367  0.3654]
# ##
# ## Number of MS: 1
#
# ## J0137-245_B7  J0522-364  J0137-245B3Spec1   : 88 lines
# ## Coordinates (J2000): 24.409777 -24.514968
# ## Galactic Coordinates (l,b): (201.393127 , -79.284295)
# ## Redshift:
# [0.837539]
# ##
# ## Number of MS: 6
#
# ## J0138-0540   : 1 lines
# ## Coordinates (J2000): 24.716047 -5.668956
# ## Galactic Coordinates (l,b): (152.790409 , -65.752881)
# ## Redshift:
# [2.004]
# ##
# ## Number of MS: 1
#
# ## J0139+1753   : 3 lines
# ## Coordinates (J2000): 24.924913 17.885431
# ## Galactic Coordinates (l,b): (138.845946 , -43.489985)
# ## Redshift:
# [2.73]
# ##
# ## Number of MS: 1
#
# ## J0141-0202   : 0 lines
# ## Coordinates (J2000): 25.390792 -2.039320
# ## Galactic Coordinates (l,b): (150.622923 , -62.185448)
# ## Redshift:
# [1.281]
# ##
# ## Number of MS: 1
#
# ## J0149+0555   : 10 lines
# ## Coordinates (J2000): 27.343212 5.931547
# ## Galactic Coordinates (l,b): (148.030210 , -54.092819)
# ## Redshift:
# [2.345]
# ##
# ## Number of MS: 2
#
# ## J0211+1051   : 4 lines
# ## Coordinates (J2000): 32.804906 10.859666
# ## Galactic Coordinates (l,b): (152.577899 , -47.367523)
# ## Redshift:
# [0.2]
# ##
# ## Number of MS: 1
#
# ## J0215-0222   : 0 lines
# ## Coordinates (J2000): 33.925072 -2.382431
# ## Galactic Coordinates (l,b): (165.707943 , -58.075629)
# ## Redshift:
# [1.178   nan   nan]
# ##
# ## Number of MS: 8
#
# ## J0219+0120   : 13 lines
# ## Coordinates (J2000): 34.779269 1.349963
# ## Galactic Coordinates (l,b): (162.988977 , -54.555414)
# ## Redshift:
# [1.623]
# ##
# ## Number of MS: 5
#
# ## J0220+3241   : 0 lines
# ## Coordinates (J2000): 35.200221 32.685129
# ## Galactic Coordinates (l,b): (143.882417 , -26.525333)
# ## Redshift:
# [1.62]
# ##
# ## Number of MS: 3
#
# ## J0223-5347   : 0 lines
# ## Coordinates (J2000): 35.878644 -53.794418
# ## Galactic Coordinates (l,b): (276.771681 , -58.405483)
# ## Redshift:
# [0.569]
# ##
# ## Number of MS: 1
#
# ## J0224+0659   : 28 lines
# ## Coordinates (J2000): 36.118451 6.989817
# ## Galactic Coordinates (l,b): (159.722305 , -49.120808)
# ## Redshift:
# [0.511]
# ##
# ## Number of MS: 13
#
# ## J0231-4746   : 0 lines
# ## Coordinates (J2000): 37.799183 -47.769884
# ## Galactic Coordinates (l,b): (266.295579 , -61.645443)
# ## Redshift:
# [0.765]
# ##
# ## Number of MS: 2
#
# ## J0237+2848   : 5 lines
# ## Coordinates (J2000): 39.468357 28.802497
# ## Galactic Coordinates (l,b): (149.465826 , -28.528317)
# ## Redshift:
# [1.213]
# ##
# ## Number of MS: 3
#
# ## J0238+1636  J0238+166   : 75 lines
# ## Coordinates (J2000): 39.662208 16.616465
# ## Galactic Coordinates (l,b): (156.770726 , -39.109479)
# ## Redshift:
# [0.94      nan 0.525  0.8529 0.524  0.851     nan]
# ##
# ## Number of MS: 29
#
# ## J0239+0416   : 2 lines
# ## Coordinates (J2000): 39.963596 4.272614
# ## Galactic Coordinates (l,b): (166.895430 , -49.119490)
# ## Redshift:
# [0.978]
# ##
# ## Number of MS: 2
#
# ## J0239-0234   : 5 lines
# ## Coordinates (J2000): 39.939468 -2.578032
# ## Galactic Coordinates (l,b): (174.139145 , -54.304413)
# ## Redshift:
# [1.116]
# ##
# ## Number of MS: 3
#
# ## J0241-0815   : 2 lines
# ## Coordinates (J2000): 40.269994 -8.255764
# ## Galactic Coordinates (l,b): (182.019458 , -57.925476)
# ## Redshift:
# [0.005037]
# ##
# ## Number of MS: 3
#
# ## J0301+0118   : 12 lines
# ## Coordinates (J2000): 45.348362 1.309999
# ## Galactic Coordinates (l,b): (175.917534 , -47.738256)
# ## Redshift:
# [1.221]
# ##
# ## Number of MS: 3
#
# ## J0309+1029   : 1 lines
# ## Coordinates (J2000): 47.265098 10.487873
# ## Galactic Coordinates (l,b): (169.179159 , -39.718995)
# ## Redshift:
# [0.863]
# ##
# ## Number of MS: 2
#
# ## J0327+0044   : 5 lines
# ## Coordinates (J2000): 51.996731 0.739646
# ## Galactic Coordinates (l,b): (182.880529 , -43.185549)
# ## Redshift:
# [1.35927]
# ##
# ## Number of MS: 4
#
# ## J0334-4008  J0334-401   : 10 lines
# ## Coordinates (J2000): 53.556894 -40.140388
# ## Galactic Coordinates (l,b): (244.763965 , -54.074940)
# ## Redshift:
# [1.445]
# ##
# ## Number of MS: 12
#
# ## J0339-0133   : 2 lines
# ## Coordinates (J2000): 54.754109 -1.554891
# ## Galactic Coordinates (l,b): (187.658986 , -42.424116)
# ## Redshift:
# [3.197 3.061]
# ##
# ## Number of MS: 1
#
# ## J0339-0146   : 11 lines
# ## Coordinates (J2000): 54.878907 -1.776612
# ## Galactic Coordinates (l,b): (188.001212 , -42.454695)
# ## Redshift:
# [0.852]
# ##
# ## Number of MS: 5
#
# ## J0403-360  J040353-360513  B0402-362   : 25 lines
# ## Coordinates (J2000): 60.973958 -36.083865
# ## Galactic Coordinates (l,b): (237.742915 , -48.483325)
# ## Redshift:
# [1.422838 0.797   ]
# ##
# ## Number of MS: 13
#
# ## J0418+380   : 18 lines
# ## Coordinates (J2000): 64.588655 38.026611
# ## Galactic Coordinates (l,b): (161.675527 , -8.819784)
# ## Redshift:
# [0.0485]
# ##
# ## Number of MS: 4
#
# ## J0423-013  J042315-012034  J0423-0120   : 266 lines
# ## Coordinates (J2000): 65.815836 -1.342518
# ## Galactic Coordinates (l,b): (195.290111 , -33.139930)
# ## Redshift:
# [0.916087 0.633   ]
# ##
# ## Number of MS: 103
#
# ## J0426+0518   : 0 lines
# ## Coordinates (J2000): 66.652517 5.305520
# ## Galactic Coordinates (l,b): (189.363016 , -28.770588)
# ## Redshift:
# [1.333]
# ##
# ## Number of MS: 1
#
# ## J0427-0700   : 4 lines
# ## Coordinates (J2000): 66.858997 -7.008684
# ## Galactic Coordinates (l,b): (201.839550 , -35.089689)
# ## Redshift:
# [nan]
# ##
# ## Number of MS: 2
#
# ## J0438+3004   : 0 lines
# ## Coordinates (J2000): 69.520618 30.079311
# ## Galactic Coordinates (l,b): (170.411503 , -11.228379)
# ## Redshift:
# [1.454]
# ##
# ## Number of MS: 2
#
# ## J0440+2728   : 0 lines
# ## Coordinates (J2000): 70.115579 27.477967
# ## Galactic Coordinates (l,b): (172.782959 , -12.514191)
# ## Redshift:
# [nan]
# ##
# ## Number of MS: 1
#
# ## J0501-0159   : 12 lines
# ## Coordinates (J2000): 75.303375 -1.987293
# ## Galactic Coordinates (l,b): (201.451028 , -25.295605)
# ## Redshift:
# [2.286  1.999  2.0385 2.089  1.5607 0.8901 1.5271]
# ##
# ## Number of MS: 12
#
# ## J0509+1806   : 35 lines
# ## Coordinates (J2000): 77.428800 18.108420
# ## Galactic Coordinates (l,b): (184.603718 , -12.798400)
# ## Redshift:
# [nan]
# ##
# ## Number of MS: 3
#
# ## J051002+180041  J0510+180  J0510+1800   : 91 lines
# ## Coordinates (J2000): 77.509871 18.011550
# ## Galactic Coordinates (l,b): (184.730346 , -12.789667)
# ## Redshift:
# [0.416]
# ##
# ## Number of MS: 23
#
# ## J0517-0520   : 26 lines
# ## Coordinates (J2000): 79.367126 -5.344678
# ## Galactic Coordinates (l,b): (206.801378 , -23.309895)
# ## Redshift:
# [nan]
# ##
# ## Number of MS: 15
#
# ## J0519-4546   : 0 lines
# ## Coordinates (J2000): 79.957179 -45.778848
# ## Galactic Coordinates (l,b): (251.596740 , -34.634275)
# ## Redshift:
# [0.035058]
# ##
# ## Number of MS: 5
#
# ## J0521+1638   : 0 lines
# ## Coordinates (J2000): 80.291191 16.639459
# ## Galactic Coordinates (l,b): (187.404939 , -11.343496)
# ## Redshift:
# [0.759]
# ##
# ## Number of MS: 1
#
# ## J0522-364  J0522-3627   : 25 lines
# ## Coordinates (J2000): 80.741603 -36.458570
# ## Galactic Coordinates (l,b): (240.607692 , -32.715967)
# ## Redshift:
# [0.056546]
# ##
# ## Number of MS: 12
#
# ## J0532-0307   : 1 lines
# ## Coordinates (J2000): 83.031330 -3.118622
# ## Galactic Coordinates (l,b): (206.492125 , -19.040964)
# ## Redshift:
# [nan nan nan nan]
# ##
# ## Number of MS: 1
#
# ## J0538-440  B0537-441  J0538-4405   : 40 lines
# ## Coordinates (J2000): 84.709842 -44.085816
# ## Galactic Coordinates (l,b): (250.082779 , -31.089647)
# ## Redshift:
# [0.894   nan]
# ##
# ## Number of MS: 21
#
# ## J0541-0211   : 3 lines
# ## Coordinates (J2000): 85.340401 -2.185663
# ## Galactic Coordinates (l,b): (206.749794 , -16.564977)
# ## Redshift:
# [nan]
# ##
# ## Number of MS: 4
#
# ## J0541-0541   : 0 lines
# ## Coordinates (J2000): 85.408681 -5.697063
# ## Galactic Coordinates (l,b): (210.054044 , -18.109997)
# ## Redshift:
# [0.839   nan]
# ##
# ## Number of MS: 2
#
# ## J0550-5732   : 25 lines
# ## Coordinates (J2000): 87.539918 -57.540110
# ## Galactic Coordinates (l,b): (265.906056 , -30.726756)
# ## Redshift:
# [2.001]
# ##
# ## Number of MS: 3
#
# ## J0601-7036  j0601-7036   : 1 lines
# ## Coordinates (J2000): 90.296866 -70.602442
# ## Galactic Coordinates (l,b): (281.035183 , -29.629669)
# ## Redshift:
# [2.409]
# ##
# ## Number of MS: 10
#
# ## J0604+2429   : 0 lines
# ## Coordinates (J2000): 91.229672 24.498621
# ## Galactic Coordinates (l,b): (186.005315 , 1.479829)
# ## Redshift:
# [nan]
# ##
# ## Number of MS: 3
#
# ## J0607-0834   : 10 lines
# ## Coordinates (J2000): 91.998747 -8.580550
# ## Galactic Coordinates (l,b): (215.751667 , -13.523808)
# ## Redshift:
# [0.872]
# ##
# ## Number of MS: 3
#
# ## J0635-7516   : 0 lines
# ## Coordinates (J2000): 98.943783 -75.271338
# ## Galactic Coordinates (l,b): (286.368358 , -27.158417)
# ## Redshift:
# [0.653 0.152]
# ##
# ## Number of MS: 3
#
# ## J0730-1141   : 6 lines
# ## Coordinates (J2000): 112.579635 -11.686833
# ## Galactic Coordinates (l,b): (227.767910 , 3.140348)
# ## Redshift:
# [1.591]
# ##
# ## Number of MS: 3
#
# ## J0750+1231   : 0 lines
# ## Coordinates (J2000): 117.716857 12.518008
# ## Galactic Coordinates (l,b): (208.160547 , 18.760512)
# ## Redshift:
# [0.889]
# ##
# ## Number of MS: 1
#
# ## J0823+2223   : 0 lines
# ## Coordinates (J2000): 125.853160 22.384250
# ## Galactic Coordinates (l,b): (201.364273 , 29.676746)
# ## Redshift:
# [0.951   nan]
# ##
# ## Number of MS: 2
#
# ## J0837+2454   : 0 lines
# ## Coordinates (J2000): 129.417690 24.906423
# ## Galactic Coordinates (l,b): (199.758149 , 33.569203)
# ## Redshift:
# [1.126355      nan]
# ##
# ## Number of MS: 1
#
# ## J0854+201  J0854+201_setup7  J0854+201_setup4  J0854+201_setup5  J0854+201_setup6  J0854+201_setup3  J0854+2006   : 102 lines
# ## Coordinates (J2000): 133.703645 20.108511
# ## Galactic Coordinates (l,b): (206.812119 , 35.820891)
# ## Redshift:
# [0.3056    nan]
# ##
# ## Number of MS: 25
#
# ## J0909+013   : 84 lines
# ## Coordinates (J2000): 137.292048 1.359894
# ## Galactic Coordinates (l,b): (228.944546 , 30.924697)
# ## Redshift:
# [1.024905]
# ##
# ## Number of MS: 21
#
# ## J0914+0245   : 0 lines
# ## Coordinates (J2000): 138.657973 2.766457
# ## Galactic Coordinates (l,b): (228.352116 , 32.819054)
# ## Redshift:
# [0.426677]
# ##
# ## Number of MS: 2
#
# ## J1008+063  J1008+0621   : 1 lines
# ## Coordinates (J2000): 152.003401 6.355893
# ## Galactic Coordinates (l,b): (233.521801 , 46.012282)
# ## Redshift:
# [1.72]
# ##
# ## Number of MS: 9
#
# ## J1011-0423   : 16 lines
# ## Coordinates (J2000): 152.876000 -4.391030
# ## Galactic Coordinates (l,b): (245.959588 , 40.167341)
# ## Redshift:
# [1.588]
# ##
# ## Number of MS: 5
#
# ## J1037-295  J1037-2934   : 29 lines
# ## Coordinates (J2000): 159.316999 -29.567448
# ## Galactic Coordinates (l,b): (270.952106 , 24.846035)
# ## Redshift:
# [0.312   nan]
# ##
# ## Number of MS: 14
#
# ## J1038-2151   : 0 lines
# ## Coordinates (J2000): 159.674291 -21.851973
# ## Galactic Coordinates (l,b): (266.388364 , 31.439434)
# ## Redshift:
# [0.585]
# ##
# ## Number of MS: 1
#
# ## J1039-1541   : 0 lines
# ## Coordinates (J2000): 159.777938 -15.685192
# ## Galactic Coordinates (l,b): (262.115331 , 36.489181)
# ## Redshift:
# [0.525]
# ##
# ## Number of MS: 1
#
# ## J1048-1909   : 0 lines
# ## Coordinates (J2000): 162.027586 -19.159924
# ## Galactic Coordinates (l,b): (266.751387 , 34.905256)
# ## Redshift:
# [0.595]
# ##
# ## Number of MS: 1
#
# ## J1058+015  J1058+0133   : 34 lines
# ## Coordinates (J2000): 164.623355 1.566340
# ## Galactic Coordinates (l,b): (251.510605 , 52.773983)
# ## Redshift:
# [0.89]
# ##
# ## Number of MS: 23
#
# ## J1107-4449   : 0 lines
# ## Coordinates (J2000): 166.786225 -44.818783
# ## Galactic Coordinates (l,b): (284.170755 , 14.220252)
# ## Redshift:
# [1.598]
# ##
# ## Number of MS: 3
#
# ## J1130-1449   : 8 lines
# ## Coordinates (J2000): 172.529386 -14.824274
# ## Galactic Coordinates (l,b): (275.280805 , 43.638336)
# ## Redshift:
# [1.184    1.189059      nan 0.3127        nan]
# ##
# ## Number of MS: 3
#
# ## J1139-1350   : 0 lines
# ## Coordinates (J2000): 174.794594 -13.845455
# ## Galactic Coordinates (l,b): (277.525158 , 45.431678)
# ## Redshift:
# [0.556458]
# ##
# ## Number of MS: 5
#
# ## J1146+3958   : 0 lines
# ## Coordinates (J2000): 176.742908 39.976196
# ## Galactic Coordinates (l,b): (164.950602 , 71.470463)
# ## Redshift:
# [1.090069]
# ##
# ## Number of MS: 1
#
# ## J1146-2859   : 0 lines
# ## Coordinates (J2000): 176.609119 -28.988474
# ## Galactic Coordinates (l,b): (286.200106 , 31.762587)
# ## Redshift:
# [0.45]
# ##
# ## Number of MS: 1
#
# ## J1150+2417   : 2 lines
# ## Coordinates (J2000): 177.580051 24.298288
# ## Galactic Coordinates (l,b): (221.148515 , 75.955616)
# ## Redshift:
# [0.2]
# ##
# ## Number of MS: 16
#
# ## J1159+2914   : 0 lines
# ## Coordinates (J2000): 179.882641 29.245507
# ## Galactic Coordinates (l,b): (199.413633 , 78.374329)
# ## Redshift:
# [0.724688]
# ##
# ## Number of MS: 1
#
# ## J1159-0940   : 0 lines
# ## Coordinates (J2000): 179.802966 -9.681125
# ## Galactic Coordinates (l,b): (282.173563 , 51.073512)
# ## Redshift:
# [nan]
# ##
# ## Number of MS: 1
#
# ## J1159-2142   : 6 lines
# ## Coordinates (J2000): 179.839302 -21.712476
# ## Galactic Coordinates (l,b): (287.178575 , 39.560817)
# ## Redshift:
# [0.617]
# ##
# ## Number of MS: 2
#
# ## J1209-2406   : 0 lines
# ## Coordinates (J2000): 182.260188 -24.105766
# ## Galactic Coordinates (l,b): (290.671383 , 37.754541)
# ## Redshift:
# [1.299]
# ##
# ## Number of MS: 2
#
# ## J1215+3448   : 2 lines
# ## Coordinates (J2000): 183.981671 34.804228
# ## Galactic Coordinates (l,b): (165.480245 , 79.199124)
# ## Redshift:
# [0.857]
# ##
# ## Number of MS: 2
#
# ## J1215-1731   : 15 lines
# ## Coordinates (J2000): 183.944799 -17.529279
# ## Galactic Coordinates (l,b): (290.972406 , 44.512834)
# ## Redshift:
# [nan nan nan nan nan nan]
# ##
# ## Number of MS: 7
#
# ## J1224+0330   : 0 lines
# ## Coordinates (J2000): 186.218425 3.513970
# ## Galactic Coordinates (l,b): (286.739864 , 65.547182)
# ## Redshift:
# [0.954974]
# ##
# ## Number of MS: 3
#
# ## J1224+213  J1224+2122   : 41 lines
# ## Coordinates (J2000): 186.226910 21.379552
# ## Galactic Coordinates (l,b): (255.073384 , 81.659786)
# ## Redshift:
# [0.432]
# ##
# ## Number of MS: 10
#
# ## J1225+1253   : 0 lines
# ## Coordinates (J2000): 186.265597 12.886983
# ## Galactic Coordinates (l,b): (278.204449 , 74.478361)
# ## Redshift:
# [0.003392]
# ##
# ## Number of MS: 13
#
# ## J1229+020  3c273  3c273_B6S12  3c273_B6S13  3c273_B6S2  3c273_B6S14  3c273_B7P1S2  J1229+0203   : 307 lines
# ## Coordinates (J2000): 187.277916 2.052388
# ## Galactic Coordinates (l,b): (289.950882 , 64.359975)
# ## Redshift:
# [0.158339 0.0876   0.021562 0.025875 0.029007 0.032386 0.0488   0.061
#  0.00728  0.12     0.1466   0.0033   0.0052   0.049    0.0665   0.0835
#  0.0899   0.0901   0.0635  ]
# ##
# ## Number of MS: 110
#
# ## J1232-0224   : 5 lines
# ## Coordinates (J2000): 188.000067 -2.401332
# ## Galactic Coordinates (l,b): (293.156194 , 60.100963)
# ## Redshift:
# [     nan 0.7005   1.045059 0.831         nan 0.7571   0.395         nan
#       nan]
# ##
# ## Number of MS: 1
#
# ## J1239+0730   : 7 lines
# ## Coordinates (J2000): 189.852451 7.504775
# ## Galactic Coordinates (l,b): (294.112708 , 70.170292)
# ## Redshift:
# [0.4 nan]
# ##
# ## Number of MS: 4
#
# ## J1243+1622   : 4 lines
# ## Coordinates (J2000): 190.990205 16.381498
# ## Galactic Coordinates (l,b): (293.393042 , 79.114515)
# ## Redshift:
# [0.5551    nan]
# ##
# ## Number of MS: 3
#
# ## J1309+119   : 0 lines
# ## Coordinates (J2000): 197.391385 11.906820
# ## Galactic Coordinates (l,b): (319.423140 , 74.195303)
# ## Redshift:
# [0.415]
# ##
# ## Number of MS: 2
#
# ## J1312-0424   : 0 lines
# ## Coordinates (J2000): 198.212089 -4.413859
# ## Galactic Coordinates (l,b): (313.050938 , 58.036619)
# ## Redshift:
# [0.8249]
# ##
# ## Number of MS: 1
#
# ## J1319-0049   : 0 lines
# ## Coordinates (J2000): 199.911526 -0.827761
# ## Galactic Coordinates (l,b): (317.709907 , 61.232016)
# ## Redshift:
# [0.890996      nan      nan 0.87          nan      nan      nan      nan
#       nan]
# ##
# ## Number of MS: 8
#
# ## J1331+3030   : 2 lines
# ## Coordinates (J2000): 202.784534 30.509155
# ## Galactic Coordinates (l,b): (56.524349 , 80.674657)
# ## Redshift:
# [0.849934 0.69218       nan      nan      nan      nan      nan]
# ##
# ## Number of MS: 1
#
# ## J1332+0200   : 0 lines
# ## Coordinates (J2000): 203.221961 2.012694
# ## Galactic Coordinates (l,b): (326.251627 , 62.992409)
# ## Redshift:
# [0.215567]
# ##
# ## Number of MS: 1
#
# ## J1337-1257   : 9 lines
# ## Coordinates (J2000): 204.415763 -12.956859
# ## Galactic Coordinates (l,b): (320.024002 , 48.374854)
# ## Redshift:
# [0.539   nan]
# ##
# ## Number of MS: 4
#
# ## J1415+1320   : 8 lines
# ## Coordinates (J2000): 213.995073 13.339920
# ## Galactic Coordinates (l,b): (2.211246 , 65.913236)
# ## Redshift:
# [0.24671]
# ##
# ## Number of MS: 3
#
# ## J1419+3821   : 0 lines
# ## Coordinates (J2000): 214.944224 38.363465
# ## Galactic Coordinates (l,b): (69.798057 , 68.377981)
# ## Redshift:
# [1.829579]
# ##
# ## Number of MS: 1
#
# ## J1420-0642   : 0 lines
# ## Coordinates (J2000): 215.074823 -6.702236
# ## Galactic Coordinates (l,b): (338.603323 , 49.913705)
# ## Redshift:
# [nan]
# ##
# ## Number of MS: 2
#
# ## J1449-0045   : 0 lines
# ## Coordinates (J2000): 222.319126 -0.755341
# ## Galactic Coordinates (l,b): (353.200841 , 50.249495)
# ## Redshift:
# [nan]
# ##
# ## Number of MS: 1
#
# ## J1505+0326   : 0 lines
# ## Coordinates (J2000): 226.276988 3.441892
# ## Galactic Coordinates (l,b): (2.226587 , 50.254361)
# ## Redshift:
# [0.407882]
# ##
# ## Number of MS: 1
#
# ## J1517-243  J1517-2422   : 31 lines
# ## Coordinates (J2000): 229.424221 -24.372077
# ## Galactic Coordinates (l,b): (340.680629 , 27.578031)
# ## Redshift:
# [0.049031]
# ##
# ## Number of MS: 6
#
# ## J1549+0237   : 0 lines
# ## Coordinates (J2000): 237.372654 2.616990
# ## Galactic Coordinates (l,b): (10.845793 , 40.904406)
# ## Redshift:
# [0.414375]
# ##
# ## Number of MS: 2
#
# ## J1550+0527   : 0 lines
# ## Coordinates (J2000): 237.646954 5.452902
# ## Galactic Coordinates (l,b): (14.216436 , 42.230835)
# ## Redshift:
# [1.422]
# ##
# ## Number of MS: 4
#
# ## J1650+0824   : 0 lines
# ## Coordinates (J2000): 252.656511 8.414509
# ## Galactic Coordinates (l,b): (26.479805 , 30.639039)
# ## Redshift:
# [1.965]
# ##
# ## Number of MS: 1
#
# ## J1733-1304   : 14 lines
# ## Coordinates (J2000): 263.261274 -13.080430
# ## Galactic Coordinates (l,b): (12.032313 , 10.811496)
# ## Redshift:
# [0.902]
# ##
# ## Number of MS: 3
#
# ## J1744-3116   : 13 lines
# ## Coordinates (J2000): 266.098243 -31.276746
# ## Galactic Coordinates (l,b): (357.865080 , -0.995622)
# ## Redshift:
# [nan nan nan]
# ##
# ## Number of MS: 5
#
# ## J1832-2039   : 50 lines
# ## Coordinates (J2000): 278.046027 -20.663390
# ## Galactic Coordinates (l,b): (12.364091 , -5.222860)
# ## Redshift:
# [0.1033]
# ##
# ## Number of MS: 11
#
# ## J1833-2103   : 83 lines
# ## Coordinates (J2000): 278.416000 -21.061466
# ## Galactic Coordinates (l,b): (12.165304 , -5.711559)
# ## Redshift:
# [    nan     nan     nan 2.507   0.8858  0.1926  0.88582     nan]
# ##
# ## Number of MS: 11
#
# ## J1924-292  QSO B1921-293  J1924-2914   : 217 lines
# ## Coordinates (J2000): 291.212733 -29.241700
# ## Galactic Coordinates (l,b): (9.344071 , -19.606787)
# ## Redshift:
# [0.352627      nan]
# ##
# ## Number of MS: 41
#
# ## J2025+3343   : 0 lines
# ## Coordinates (J2000): 306.295175 33.716726
# ## Galactic Coordinates (l,b): (73.129143 , -2.367852)
# ## Redshift:
# [0.219]
# ##
# ## Number of MS: 1
#
# ## J2056-4714   : 0 lines
# ## Coordinates (J2000): 314.068166 -47.246563
# ## Galactic Coordinates (l,b): (352.590573 , -40.381357)
# ## Redshift:
# [1.489]
# ##
# ## Number of MS: 3
#
# ## J2101+036   : 0 lines
# ## Coordinates (J2000): 315.411809 3.692034
# ## Galactic Coordinates (l,b): (52.690804 , -26.648722)
# ## Redshift:
# [1.013]
# ##
# ## Number of MS: 5
#
# ## J2130-0927   : 3 lines
# ## Coordinates (J2000): 322.579534 -9.460399
# ## Galactic Coordinates (l,b): (43.470195 , -39.490363)
# ## Redshift:
# [0.78  nan]
# ##
# ## Number of MS: 1
#
# ## J2148+0657  J2148+069   : 7 lines
# ## Coordinates (J2000): 327.022744 6.960723
# ## Galactic Coordinates (l,b): (63.656016 , -34.071639)
# ## Redshift:
# [0.99   0.8648 0.8577 0.849  0.8479 0.818  0.7308 0.7    0.683  0.6404
#  0.6156 0.5936 0.8797 0.5266 0.5178 0.4782 0.4587 0.6557 0.781  0.7913
#  0.8983 0.9765]
# ##
# ## Number of MS: 13
#
# ## J2157-694   : 0 lines
# ## Coordinates (J2000): 329.274919 -69.689913
# ## Galactic Coordinates (l,b): (321.316466 , -40.647211)
# ## Redshift:
# [0.028273      nan]
# ##
# ## Number of MS: 3
#
# ## J2214+0711   : 0 lines
# ## Coordinates (J2000): 333.536923 7.195109
# ## Galactic Coordinates (l,b): (69.209069 , -38.752221)
# ## Redshift:
# [nan nan]
# ##
# ## Number of MS: 2
#
# ## J2225-049  3C446   : 0 lines
# ## Coordinates (J2000): 336.446914 -4.950386
# ## Galactic Coordinates (l,b): (58.959669 , -48.842787)
# ## Redshift:
# [1.404     nan    nan 0.4925    nan    nan    nan 0.8472]
# ##
# ## Number of MS: 6
#
# ## J2232+1143  J2232+117   : 1 lines
# ## Coordinates (J2000): 338.151700 11.730810
# ## Galactic Coordinates (l,b): (77.437896 , -38.582486)
# ## Redshift:
# [1.037]
# ##
# ## Number of MS: 6
#
# ## J2236+284   : 37 lines
# ## Coordinates (J2000): 339.093629 28.482615
# ## Galactic Coordinates (l,b): (90.117026 , -25.648865)
# ## Redshift:
# [0.795]
# ##
# ## Number of MS: 3
#
# ## J2253+161  3c454.3  J2253+1608   : 60 lines
# ## Coordinates (J2000): 343.490616 16.148211
# ## Galactic Coordinates (l,b): (86.111058 , -38.183817)
# ## Redshift:
# [0.859  0.8192 0.8103 0.7423 0.7132 0.6406 0.6169 0.8225 0.5857 0.8137
#  0.5207 0.1538 0.4562 0.414  0.3906 0.5641 0.8243]
# ##
# ## Number of MS: 15
#
# ## J2258-2758   : 10 lines
# ## Coordinates (J2000): 344.524850 -27.972570
# ## Galactic Coordinates (l,b): (24.386638 , -64.920395)
# ## Redshift:
# [    nan 0.92584]
# ##
# ## Number of MS: 6
#
# ## J2301-0158   : 0 lines
# ## Coordinates (J2000): 345.283244 -1.967941
# ## Galactic Coordinates (l,b): (71.836820 , -53.521007)
# ## Redshift:
# [0.778]
# ##
# ## Number of MS: 1
#
# ## J2306-0459   : 0 lines
# ## Coordinates (J2000): 346.563821 -4.996746
# ## Galactic Coordinates (l,b): (69.696812 , -56.571676)
# ## Redshift:
# [1.139   nan   nan]
# ##
# ## Number of MS: 1
#
# ## J2323-032   : 0 lines
# ## Coordinates (J2000): 350.883141 -3.284729
# ## Galactic Coordinates (l,b): (77.743689 , -58.221591)
# ## Redshift:
# [1.41]
# ##
# ## Number of MS: 3
#
# ## J2357-5311   : 0 lines
# ## Coordinates (J2000): 359.471942 -53.187136
# ## Galactic Coordinates (l,b): (320.185117 , -62.110544)
# ## Redshift:
# [1.006]
# ##
# ## Number of MS: 1
#
# ## Mars   : 105 lines
# ## Coordinates (J2000): 154.600541 12.530461
# ## Galactic Coordinates (l,b): (227.441059 , 51.363292)
# ## No redshift
#
# ## Neptune   : 132 lines
# ## Coordinates (J2000): 334.331803 -11.238529
# ## Galactic Coordinates (l,b): (49.039250 , -50.512356)
# ## No redshift
#
# ## Pallas   : 13 lines
# ## Coordinates (J2000): 143.276263 -18.002432
# ## Galactic Coordinates (l,b): (250.462556 , 24.069439)
# ## No redshift
#
# ## Titan   : 248 lines
# ## Coordinates (J2000): 210.213715 -9.912556
# ## Galactic Coordinates (l,b): (329.721588 , 49.314403)
# ## No redshift
#
# ## Uranus   : 131 lines
# ## Coordinates (J2000): 6.997441 2.256836
# ## Galactic Coordinates (l,b): (111.126941 , -60.076377)
# ## No redshift
#
#
#  Total Line: 3184
