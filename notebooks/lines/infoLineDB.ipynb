# %%
import sys
sys.path.append("/home/stephane/git/alma-calibrator/src")

import lineTools as lt

# %%
al = lt.analysisLines("lineAll.db")
res = al.getInfoDB()
# Out:
# ## Sources: 106
# ##
# ## 3C279  J1256-057  J1256-0547  3c279  J1256-057  3c279  J125610-054722  3C279_phase   : 133 lines
# ## Coordinates (J2000): 194.046527 -5.789312
# ## Galactic Coordinates (l,b): (305.104321 , 57.062407)
# ## Redshift:
# [ 0.5362  0.532   0.395 ]
# ##
# ## Number of MS: 87
#
# ## B0327-241  J0329-239   : 0 lines
# ## Coordinates (J2000): 52.475315 -23.952437
# ## Galactic Coordinates (l,b): (216.888473 , -54.259327)
# ## Redshift:
# [ 0.895    nan    nan    nan]
# ##
# ## Number of MS: 9
#
# ## Callisto   : 139 lines
# ## Coordinates (J2000): 73.597382 21.753097
# ## Galactic Coordinates (l,b): (179.405065 , -13.595230)
# ## No redshift
#
# ## Ceres   : 3 lines
# ## Coordinates (J2000): 93.816281 22.399326
# ## Galactic Coordinates (l,b): (188.990486 , 2.546137)
# ## No redshift
#
# ## Ganymede   : 11 lines
# ## Coordinates (J2000): 62.979062 20.338056
# ## Galactic Coordinates (l,b): (173.893868 , -22.122796)
# ## No redshift
#
# ## J0006-0623  J0006-063   : 4 lines
# ## Coordinates (J2000): 1.557888 -6.393149
# ## Galactic Coordinates (l,b): (93.505457 , -66.646559)
# ## Redshift:
# [ 0.346676]
# ##
# ## Number of MS: 2
#
# ## J004916-445738   : 27 lines
# ## Coordinates (J2000): 12.319267 -44.953101
# ## Galactic Coordinates (l,b): (304.180554 , -72.169911)
# ## Redshift:
# [ 0.121324]
# ##
# ## Number of MS: 6
#
# ## J0108+015   : 0 lines
# ## Coordinates (J2000): 17.161546 1.583422
# ## Galactic Coordinates (l,b): (131.827034 , -60.990778)
# ## Redshift:
# [ 2.099]
# ##
# ## Number of MS: 2
#
# ## J0116-116   : 3 lines
# ## Coordinates (J2000): 19.052175 -11.604287
# ## Galactic Coordinates (l,b): (144.668760 , -73.421844)
# ## Redshift:
# [ 0.67   nan   nan]
# ##
# ## Number of MS: 1
#
# ## J0132-169   : 26 lines
# ## Coordinates (J2000): 23.181198 -16.913478
# ## Galactic Coordinates (l,b): (168.124134 , -76.017694)
# ## Redshift:
# [ 1.02   nan]
# ##
# ## Number of MS: 12
#
# ## J0137-245_B7  J0522-364  J0137-245B3Spec1  J0137-245   : 101 lines
# ## Coordinates (J2000): 24.409777 -24.514968
# ## Galactic Coordinates (l,b): (201.393127 , -79.284295)
# ## Redshift:
# [ 0.837539]
# ##
# ## Number of MS: 13
#
# ## J0139+1753   : 1 lines
# ## Coordinates (J2000): 24.924913 17.885431
# ## Galactic Coordinates (l,b): (138.845946 , -43.489985)
# ## Redshift:
# [ 2.73]
# ##
# ## Number of MS: 1
#
# ## J0149+0555   : 2 lines
# ## Coordinates (J2000): 27.343212 5.931547
# ## Galactic Coordinates (l,b): (148.030210 , -54.092819)
# ## Redshift:
# [ 2.345]
# ##
# ## Number of MS: 1
#
# ## J0149+1857   : 4 lines
# ## Coordinates (J2000): 27.457162 18.955725
# ## Galactic Coordinates (l,b): (141.577119 , -41.792274)
# ## Redshift:
# [ 0.584]
# ##
# ## Number of MS: 2
#
# ## J0151+2744   : 0 lines
# ## Coordinates (J2000): 27.863109 27.744943
# ## Galactic Coordinates (l,b): (138.835605 , -33.266635)
# ## Redshift:
# [ 1.26]
# ##
# ## Number of MS: 1
#
# ## J0215-0222   : 0 lines
# ## Coordinates (J2000): 33.925072 -2.382431
# ## Galactic Coordinates (l,b): (165.707943 , -58.075629)
# ## Redshift:
# [ 1.178    nan]
# ##
# ## Number of MS: 3
#
# ## J0217+017   : 15 lines
# ## Coordinates (J2000): 34.453978 1.747139
# ## Galactic Coordinates (l,b): (162.139977 , -54.413160)
# ## Redshift:
# [ 1.715    1.719    1.686    1.649    1.549    1.491    1.345    1.254
#   1.64409]
# ##
# ## Number of MS: 4
#
# ## J0224+0659   : 0 lines
# ## Coordinates (J2000): 36.118451 6.989817
# ## Galactic Coordinates (l,b): (159.722305 , -49.120808)
# ## Redshift:
# [ 0.511]
# ##
# ## Number of MS: 3
#
# ## J0237+2848   : 1 lines
# ## Coordinates (J2000): 39.468357 28.802497
# ## Galactic Coordinates (l,b): (149.465826 , -28.528317)
# ## Redshift:
# [ 1.213]
# ##
# ## Number of MS: 1
#
# ## J0238+1636  J0238+166   : 14 lines
# ## Coordinates (J2000): 39.662209 16.616465
# ## Galactic Coordinates (l,b): (156.770727 , -39.109479)
# ## Redshift:
# [ 0.94       nan  0.525   0.8529  0.524   0.851      nan]
# ##
# ## Number of MS: 8
#
# ## J024600-465121   : 24 lines
# ## Coordinates (J2000): 41.500492 -46.854787
# ## Galactic Coordinates (l,b): (261.827489 , -60.093924)
# ## Redshift:
# [ 1.385]
# ##
# ## Number of MS: 6
#
# ## J0334-401  J0334-4008   : 21 lines
# ## Coordinates (J2000): 53.556894 -40.140388
# ## Galactic Coordinates (l,b): (244.763965 , -54.074940)
# ## Redshift:
# [ 1.445]
# ##
# ## Number of MS: 7
#
# ## J0349-2102   : 5 lines
# ## Coordinates (J2000): 57.490944 -21.046595
# ## Galactic Coordinates (l,b): (214.397025 , -49.012776)
# ## Redshift:
# [ 2.944  1.947]
# ##
# ## Number of MS: 2
#
# ## J0403-360  J040353-360513  B0402-362   : 24 lines
# ## Coordinates (J2000): 60.973958 -36.083865
# ## Galactic Coordinates (l,b): (237.742915 , -48.483325)
# ## Redshift:
# [ 1.422838  0.797   ]
# ##
# ## Number of MS: 18
#
# ## J0418+380  3c111   : 7 lines
# ## Coordinates (J2000): 64.588655 38.026611
# ## Galactic Coordinates (l,b): (161.675527 , -8.819784)
# ## Redshift:
# [ 0.0485]
# ##
# ## Number of MS: 5
#
# ## J0423-013  J042315-012034  J0423-0120   : 39 lines
# ## Coordinates (J2000): 65.815836 -1.342518
# ## Galactic Coordinates (l,b): (195.290111 , -33.139930)
# ## Redshift:
# [ 0.916087  0.633   ]
# ##
# ## Number of MS: 17
#
# ## J0455-462   : 34 lines
# ## Coordinates (J2000): 73.961552 -46.266300
# ## Galactic Coordinates (l,b): (251.968164 , -38.814322)
# ## Redshift:
# [ 0.8528]
# ##
# ## Number of MS: 6
#
# ## J0457-234   : 0 lines
# ## Coordinates (J2000): 74.263247 -23.414450
# ## Galactic Coordinates (l,b): (223.710454 , -34.896779)
# ## Redshift:
# [ 1.003  0.606  0.63   0.752  0.891]
# ##
# ## Number of MS: 1
#
# ## J051002+180041  J0510+180   : 13 lines
# ## Coordinates (J2000): 77.509871 18.011550
# ## Galactic Coordinates (l,b): (184.730346 , -12.789667)
# ## Redshift:
# [ 0.416]
# ##
# ## Number of MS: 14
#
# ## J0519-4546   : 7 lines
# ## Coordinates (J2000): 79.957179 -45.778848
# ## Galactic Coordinates (l,b): (251.596740 , -34.634275)
# ## Redshift:
# [ 0.035058]
# ##
# ## Number of MS: 2
#
# ## J0522-364  QSO B0521-365   : 49 lines
# ## Coordinates (J2000): 80.741600 -36.458569
# ## Galactic Coordinates (l,b): (240.607690 , -32.715969)
# ## Redshift:
# [ 0.056546]
# ##
# ## Number of MS: 47
#
# ## J0538-440  B0537-441  J053851-440507   : 68 lines
# ## Coordinates (J2000): 84.709842 -44.085816
# ## Galactic Coordinates (l,b): (250.082779 , -31.089647)
# ## Redshift:
# [ 0.894    nan]
# ##
# ## Number of MS: 48
#
# ## J054047-541822   : 38 lines
# ## Coordinates (J2000): 85.188917 -54.304833
# ## Galactic Coordinates (l,b): (262.042133 , -31.866686)
# ## No redshift
#
# ## J0541-056   : 0 lines
# ## Coordinates (J2000): 85.408681 -5.697063
# ## Galactic Coordinates (l,b): (210.054044 , -18.109997)
# ## Redshift:
# [ 0.839    nan]
# ##
# ## Number of MS: 1
#
# ## J0600-3937   : 0 lines
# ## Coordinates (J2000): 90.130906 -39.617277
# ## Galactic Coordinates (l,b): (246.047364 , -26.219798)
# ## Redshift:
# [   nan  1.661]
# ##
# ## Number of MS: 1
#
# ## J0607-085   : 9 lines
# ## Coordinates (J2000): 91.998747 -8.580550
# ## Galactic Coordinates (l,b): (215.751667 , -13.523808)
# ## Redshift:
# [ 0.872]
# ##
# ## Number of MS: 6
#
# ## J0634-2335   : 0 lines
# ## Coordinates (J2000): 98.745837 -23.586655
# ## Galactic Coordinates (l,b): (232.567739 , -13.943496)
# ## Redshift:
# [ 1.535]
# ##
# ## Number of MS: 1
#
# ## J0637-752   : 28 lines
# ## Coordinates (J2000): 98.943779 -75.271338
# ## Galactic Coordinates (l,b): (286.368358 , -27.158418)
# ## Redshift:
# [ 0.653  0.152]
# ##
# ## Number of MS: 7
#
# ## J0808-078   : 0 lines
# ## Coordinates (J2000): 122.064734 -7.852746
# ## Galactic Coordinates (l,b): (229.041652 , 13.162821)
# ## Redshift:
# [ 1.837    nan    nan]
# ##
# ## Number of MS: 1
#
# ## J0823+2223   : 3 lines
# ## Coordinates (J2000): 125.853160 22.384250
# ## Galactic Coordinates (l,b): (201.364273 , 29.676746)
# ## Redshift:
# [ 0.951    nan]
# ##
# ## Number of MS: 1
#
# ## J0854+201  J0854+201_setup7  J0854+201_setup4  J0854+201_setup5  J0854+201_setup6  J0854+201_setup3  J0854+2006   : 60 lines
# ## Coordinates (J2000): 133.703645 20.108511
# ## Galactic Coordinates (l,b): (206.812119 , 35.820891)
# ## Redshift:
# [ 0.3056     nan]
# ##
# ## Number of MS: 23
#
# ## J0909+013   : 44 lines
# ## Coordinates (J2000): 137.292048 1.359894
# ## Galactic Coordinates (l,b): (228.944546 , 30.924697)
# ## Redshift:
# [ 1.024905]
# ##
# ## Number of MS: 21
#
# ## J0927+390   : 3 lines
# ## Coordinates (J2000): 141.762558 39.039125
# ## Galactic Coordinates (l,b): (183.708452 , 46.163693)
# ## Redshift:
# [ 0.695283]
# ##
# ## Number of MS: 1
#
# ## J1008+063   : 0 lines
# ## Coordinates (J2000): 152.003401 6.355893
# ## Galactic Coordinates (l,b): (233.521801 , 46.012282)
# ## Redshift:
# [ 1.72]
# ##
# ## Number of MS: 8
#
# ## J1037-295   : 12 lines
# ## Coordinates (J2000): 159.316999 -29.567448
# ## Galactic Coordinates (l,b): (270.952106 , 24.846035)
# ## Redshift:
# [ 0.312    nan]
# ##
# ## Number of MS: 4
#
# ## J1058+015  J1058+0133   : 4 lines
# ## Coordinates (J2000): 164.623355 1.566340
# ## Galactic Coordinates (l,b): (251.510605 , 52.773983)
# ## Redshift:
# [ 0.89]
# ##
# ## Number of MS: 8
#
# ## J1107-448   : 5 lines
# ## Coordinates (J2000): 166.786226 -44.818783
# ## Galactic Coordinates (l,b): (284.170755 , 14.220252)
# ## Redshift:
# [ 1.598]
# ##
# ## Number of MS: 4
#
# ## J1130+3031   : 2 lines
# ## Coordinates (J2000): 172.676788 30.526497
# ## Galactic Coordinates (l,b): (197.257597 , 72.020762)
# ## Redshift:
# [ 0.736888  0.736964]
# ##
# ## Number of MS: 1
#
# ## J1130-148   : 11 lines
# ## Coordinates (J2000): 172.529383 -14.824274
# ## Galactic Coordinates (l,b): (275.280802 , 43.638335)
# ## Redshift:
# [ 1.184     1.189059       nan  0.3127         nan]
# ##
# ## Number of MS: 4
#
# ## J1147-382   : 7 lines
# ## Coordinates (J2000): 176.755711 -38.203062
# ## Galactic Coordinates (l,b): (289.239680 , 22.950001)
# ## Redshift:
# [ 1.048]
# ##
# ## Number of MS: 2
#
# ## J1159-0940   : 0 lines
# ## Coordinates (J2000): 179.802966 -9.681125
# ## Galactic Coordinates (l,b): (282.173563 , 51.073512)
# ## Redshift:
# [ nan]
# ##
# ## Number of MS: 1
#
# ## J1215+3448   : 2 lines
# ## Coordinates (J2000): 183.981671 34.804228
# ## Galactic Coordinates (l,b): (165.480245 , 79.199124)
# ## Redshift:
# [ 0.857]
# ##
# ## Number of MS: 2
#
# ## J1224+213  J1224+2122   : 15 lines
# ## Coordinates (J2000): 186.226910 21.379552
# ## Galactic Coordinates (l,b): (255.073384 , 81.659786)
# ## Redshift:
# [ 0.432]
# ##
# ## Number of MS: 12
#
# ## J1225+1253   : 0 lines
# ## Coordinates (J2000): 186.265597 12.886983
# ## Galactic Coordinates (l,b): (278.204449 , 74.478361)
# ## Redshift:
# [ 0.003392]
# ##
# ## Number of MS: 9
#
# ## J1229+020  3c273  3c273_B6S12  3c273_B6S13  3c273_B6S2  3c273_B6S14  3c273_B7P1S2  J1229+0203   : 148 lines
# ## Coordinates (J2000): 187.277916 2.052388
# ## Galactic Coordinates (l,b): (289.950882 , 64.359975)
# ## Redshift:
# [ 0.158339  0.0876    0.021562  0.025875  0.029007  0.032386  0.0488    0.061
#   0.00728   0.12      0.1466    0.0033    0.0052    0.049     0.0665
#   0.0835    0.0899    0.0901    0.0635  ]
# ##
# ## Number of MS: 93
#
# ## J1232-0224   : 0 lines
# ## Coordinates (J2000): 188.000067 -2.401332
# ## Galactic Coordinates (l,b): (293.156194 , 60.100963)
# ## Redshift:
# [ 0.7005    1.045059  0.831          nan  0.7571    0.395          nan
#        nan]
# ##
# ## Number of MS: 1
#
# ## J1239+0730   : 1 lines
# ## Coordinates (J2000): 189.852451 7.504775
# ## Galactic Coordinates (l,b): (294.112708 , 70.170292)
# ## Redshift:
# [ 0.4  nan]
# ##
# ## Number of MS: 4
#
# ## J1243+1622   : 3 lines
# ## Coordinates (J2000): 190.990205 16.381498
# ## Galactic Coordinates (l,b): (293.393042 , 79.114515)
# ## Redshift:
# [ 0.5551     nan]
# ##
# ## Number of MS: 3
#
# ## J1248-4559   : 1 lines
# ## Coordinates (J2000): 192.118730 -45.996439
# ## Galactic Coordinates (l,b): (302.394176 , 16.872216)
# ## Redshift:
# [ 1.02]
# ##
# ## Number of MS: 1
#
# ## J1257-319   : 0 lines
# ## Coordinates (J2000): 194.496083 -31.921348
# ## Galactic Coordinates (l,b): (304.551301 , 30.929816)
# ## Redshift:
# [ 1.924]
# ##
# ## Number of MS: 1
#
# ## J1309+119   : 0 lines
# ## Coordinates (J2000): 197.391385 11.906820
# ## Galactic Coordinates (l,b): (319.423140 , 74.195303)
# ## Redshift:
# [ 0.415]
# ##
# ## Number of MS: 2
#
# ## J1331+3030   : 0 lines
# ## Coordinates (J2000): 202.784534 30.509155
# ## Galactic Coordinates (l,b): (56.524349 , 80.674657)
# ## Redshift:
# [ 0.849934  0.69218        nan       nan       nan       nan       nan]
# ##
# ## Number of MS: 1
#
# ## J1337-129   : 8 lines
# ## Coordinates (J2000): 204.415762 -12.956859
# ## Galactic Coordinates (l,b): (320.024001 , 48.374854)
# ## Redshift:
# [ 0.539    nan]
# ##
# ## Number of MS: 3
#
# ## J1408-078   : 10 lines
# ## Coordinates (J2000): 212.235338 -7.874074
# ## Galactic Coordinates (l,b): (333.881773 , 50.281867)
# ## Redshift:
# [ 1.494]
# ##
# ## Number of MS: 3
#
# ## J1415+1320   : 8 lines
# ## Coordinates (J2000): 213.995073 13.339920
# ## Galactic Coordinates (l,b): (2.211246 , 65.913236)
# ## Redshift:
# [ 0.24671]
# ##
# ## Number of MS: 3
#
# ## J1427-4206   : 1 lines
# ## Coordinates (J2000): 216.984573 -42.105399
# ## Galactic Coordinates (l,b): (321.447335 , 17.270588)
# ## Redshift:
# [ 1.522]
# ##
# ## Number of MS: 1
#
# ## J142739-330612   : 3 lines
# ## Coordinates (J2000): 216.922338 -33.092085
# ## Galactic Coordinates (l,b): (325.187701 , 25.586293)
# ## Redshift:
# [ nan]
# ##
# ## Number of MS: 1
#
# ## J1454-377   : 0 lines
# ## Coordinates (J2000): 223.614207 -37.792540
# ## Galactic Coordinates (l,b): (328.227473 , 18.963256)
# ## Redshift:
# [ 0.314054  0.2761  ]
# ##
# ## Number of MS: 1
#
# ## J1512-090   : 0 lines
# ## Coordinates (J2000): 228.210554 -9.099953
# ## Galactic Coordinates (l,b): (351.289250 , 40.138743)
# ## Redshift:
# [ 0.36   0.351]
# ##
# ## Number of MS: 1
#
# ## J1517-243   : 2 lines
# ## Coordinates (J2000): 229.424221 -24.372077
# ## Galactic Coordinates (l,b): (340.680629 , 27.578031)
# ## Redshift:
# [ 0.049031]
# ##
# ## Number of MS: 6
#
# ## J1604-446   : 13 lines
# ## Coordinates (J2000): 241.129253 -44.692215
# ## Galactic Coordinates (l,b): (335.155756 , 5.764506)
# ## Redshift:
# [ nan]
# ##
# ## Number of MS: 14
#
# ## J1625-254   : 0 lines
# ## Coordinates (J2000): 246.445382 -25.460646
# ## Galactic Coordinates (l,b): (352.140386 , 16.318666)
# ## Redshift:
# [ 0.786]
# ##
# ## Number of MS: 1
#
# ## J1700-261   : 72 lines
# ## Coordinates (J2000): 255.221475 -26.181035
# ## Galactic Coordinates (l,b): (356.702106 , 9.747720)
# ## Redshift:
# [ nan]
# ##
# ## Number of MS: 6
#
# ## J1717-337   : 62 lines
# ## Coordinates (J2000): 259.400121 -33.702451
# ## Galactic Coordinates (l,b): (352.735013 , 2.392167)
# ## Redshift:
# [ nan]
# ##
# ## Number of MS: 9
#
# ## J1733-1304  B1730-130  nrao530  J1733-130  NRAO530   : 68 lines
# ## Coordinates (J2000): 263.261274 -13.080430
# ## Galactic Coordinates (l,b): (12.032313 , 10.811496)
# ## Redshift:
# [ 0.902]
# ##
# ## Number of MS: 40
#
# ## J1744-3116   : 10 lines
# ## Coordinates (J2000): 266.098243 -31.276746
# ## Galactic Coordinates (l,b): (357.865080 , -0.995622)
# ## Redshift:
# [ nan  nan  nan]
# ##
# ## Number of MS: 4
#
# ## J1751+096   : 0 lines
# ## Coordinates (J2000): 267.886744 9.650202
# ## Galactic Coordinates (l,b): (34.919453 , 17.645144)
# ## Redshift:
# [ 0.322    nan]
# ##
# ## Number of MS: 1
#
# ## J1911-201   : 29 lines
# ## Coordinates (J2000): 287.790220 -20.115308
# ## Galactic Coordinates (l,b): (16.874420 , -13.217449)
# ## Redshift:
# [ 1.119]
# ##
# ## Number of MS: 13
#
# ## J1924-292  QSO B1921-293  J1924-2914  B1921-293   : 68 lines
# ## Coordinates (J2000): 291.212733 -29.241700
# ## Galactic Coordinates (l,b): (9.344071 , -19.606787)
# ## Redshift:
# [ 0.352627       nan]
# ##
# ## Number of MS: 54
#
# ## J1945-552   : 2 lines
# ## Coordinates (J2000): 296.350953 -55.346900
# ## Galactic Coordinates (l,b): (342.394898 , -29.548437)
# ## Redshift:
# [ 0.015451]
# ##
# ## Number of MS: 1
#
# ## J2025+3343   : 0 lines
# ## Coordinates (J2000): 306.295175 33.716726
# ## Galactic Coordinates (l,b): (73.129143 , -2.367852)
# ## Redshift:
# [ 0.219]
# ##
# ## Number of MS: 1
#
# ## J2025-0735   : 0 lines
# ## Coordinates (J2000): 306.419418 -7.597969
# ## Galactic Coordinates (l,b): (36.897390 , -24.387327)
# ## Redshift:
# [ 1.388]
# ##
# ## Number of MS: 1
#
# ## J2056-472   : 13 lines
# ## Coordinates (J2000): 314.068166 -47.246563
# ## Galactic Coordinates (l,b): (352.590573 , -40.381357)
# ## Redshift:
# [ 1.489]
# ##
# ## Number of MS: 4
#
# ## J2101+036   : 0 lines
# ## Coordinates (J2000): 315.411809 3.692034
# ## Galactic Coordinates (l,b): (52.690804 , -26.648722)
# ## Redshift:
# [ 1.013]
# ##
# ## Number of MS: 5
#
# ## J2101-295   : 0 lines
# ## Coordinates (J2000): 315.256917 -29.557732
# ## Galactic Coordinates (l,b): (15.791766 , -39.771362)
# ## Redshift:
# [ 1.492    nan    nan]
# ##
# ## Number of MS: 1
#
# ## J2130-0927   : 0 lines
# ## Coordinates (J2000): 322.579534 -9.460399
# ## Galactic Coordinates (l,b): (43.470195 , -39.490363)
# ## Redshift:
# [ 0.78   nan]
# ##
# ## Number of MS: 1
#
# ## J2148+0657  J2148+069   : 4 lines
# ## Coordinates (J2000): 327.022744 6.960723
# ## Galactic Coordinates (l,b): (63.656016 , -34.071639)
# ## Redshift:
# [ 0.99    0.8648  0.8577  0.849   0.8479  0.818   0.7308  0.7     0.683
#   0.6404  0.6156  0.5936  0.8797  0.5266  0.5178  0.4782  0.4587  0.6557
#   0.781   0.7913  0.8983  0.9765]
# ##
# ## Number of MS: 12
#
# ## J2156-0037   : 1 lines
# ## Coordinates (J2000): 329.061491 -0.617943
# ## Galactic Coordinates (l,b): (57.712792 , -40.335335)
# ## Redshift:
# [ 0.495]
# ##
# ## Number of MS: 1
#
# ## J2157-694   : 22 lines
# ## Coordinates (J2000): 329.274919 -69.689913
# ## Galactic Coordinates (l,b): (321.316466 , -40.647211)
# ## Redshift:
# [ 0.028273       nan]
# ##
# ## Number of MS: 11
#
# ## J2225-049  3C446   : 0 lines
# ## Coordinates (J2000): 336.446914 -4.950386
# ## Galactic Coordinates (l,b): (58.959669 , -48.842787)
# ## Redshift:
# [ 1.404      nan  0.4925     nan     nan     nan  0.8472]
# ##
# ## Number of MS: 6
#
# ## J2232+117  J2232+1143   : 2 lines
# ## Coordinates (J2000): 338.151704 11.730807
# ## Galactic Coordinates (l,b): (77.437898 , -38.582491)
# ## Redshift:
# [ 1.037]
# ##
# ## Number of MS: 6
#
# ## J2236+284  J2236+2828   : 21 lines
# ## Coordinates (J2000): 339.093629 28.482615
# ## Galactic Coordinates (l,b): (90.117026 , -25.648865)
# ## Redshift:
# [ 0.795]
# ##
# ## Number of MS: 4
#
# ## J2239-5701   : 25 lines
# ## Coordinates (J2000): 339.799583 -57.016944
# ## Galactic Coordinates (l,b): (331.807672 , -52.050648)
# ## Redshift:
# [ 0.5686]
# ##
# ## Number of MS: 6
#
# ## J2241+0953   : 1 lines
# ## Coordinates (J2000): 340.457155 9.897901
# ## Galactic Coordinates (l,b): (78.167408 , -41.441694)
# ## Redshift:
# [ 1.707]
# ##
# ## Number of MS: 1
#
# ## J2253+161  3c454.3  J2253+1608   : 59 lines
# ## Coordinates (J2000): 343.490616 16.148211
# ## Galactic Coordinates (l,b): (86.111058 , -38.183817)
# ## Redshift:
# [ 0.859   0.8192  0.8103  0.7423  0.7132  0.6406  0.6169  0.8225  0.5857
#   0.8137  0.5207  0.1538  0.4562  0.414   0.3906  0.5641  0.8243]
# ##
# ## Number of MS: 28
#
# ## J2257+0743   : 5 lines
# ## Coordinates (J2000): 344.322096 7.720084
# ## Galactic Coordinates (l,b): (80.425350 , -45.521952)
# ## Redshift:
# [ 0.19]
# ##
# ## Number of MS: 2
#
# ## J2258-2758  J2258-279   : 8 lines
# ## Coordinates (J2000): 344.524850 -27.972570
# ## Galactic Coordinates (l,b): (24.386638 , -64.920395)
# ## Redshift:
# [     nan  0.92584]
# ##
# ## Number of MS: 4
#
# ## J2301-0158   : 0 lines
# ## Coordinates (J2000): 345.283244 -1.967941
# ## Galactic Coordinates (l,b): (71.836820 , -53.521007)
# ## Redshift:
# [ 0.778]
# ##
# ## Number of MS: 1
#
# ## J2306-0459   : 0 lines
# ## Coordinates (J2000): 346.563821 -4.996746
# ## Galactic Coordinates (l,b): (69.696812 , -56.571676)
# ## Redshift:
# [ 1.139    nan    nan]
# ##
# ## Number of MS: 1
#
# ## J2323-032   : 0 lines
# ## Coordinates (J2000): 350.883141 -3.284729
# ## Galactic Coordinates (l,b): (77.743689 , -58.221591)
# ## Redshift:
# [ 1.41]
# ##
# ## Number of MS: 3
#
# ## J2333-237   : 28 lines
# ## Coordinates (J2000): 353.480167 -23.727961
# ## Galactic Coordinates (l,b): (39.627382 , -72.190297)
# ## Redshift:
# [ 0.0477]
# ##
# ## Number of MS: 7
#
# ## Mars   : 103 lines
# ## Coordinates (J2000): 154.600541 12.530461
# ## Galactic Coordinates (l,b): (227.441059 , 51.363292)
# ## No redshift
#
# ## Neptune   : 315 lines
# ## Coordinates (J2000): 334.331803 -11.238529
# ## Galactic Coordinates (l,b): (49.039250 , -50.512356)
# ## No redshift
#
# ## Pallas   : 7 lines
# ## Coordinates (J2000): 143.276263 -18.002432
# ## Galactic Coordinates (l,b): (250.462556 , 24.069439)
# ## No redshift
#
# ## Titan   : 178 lines
# ## Coordinates (J2000): 210.213715 -9.912556
# ## Galactic Coordinates (l,b): (329.721588 , 49.314403)
# ## No redshift
#
# ## Uranus   : 143 lines
# ## Coordinates (J2000): 6.997441 2.256836
# ## Galactic Coordinates (l,b): (111.126941 , -60.076377)
# ## No redshift
#
#
#  Total Line: 2462
