# %%
import sys
sys.path.append('../../src/utils/')

from galenv import *

# %matplotlib inline

# %%
primary= ['J0541-0211', 'J1733-3722', 'J1610-3958', 'J1743-0350', 'J2253+1608', 
 'J1851+0035', 'J0541-0541', 'J0601-7036', 'J1130-1449', 'J1305-4928', 
 'J0336+3218', 'J0006-0623', 'J1717-3342', 'J1833-210B', 'J0237+2848', 
 'J0750+1231', 'J1751+0939', 'J0948+0022', 'J1107-4449', 'J1256-0547', 
 'J1830+0619', 'J1225+1253']

# %%
ga = Galenv()

# %%
for obj in primary:
    name = "PKS "+obj
    try:
        ga.conedv_byname(name, 1.0, 1000.0, show=True, savefig=False)
    except:
        print("No")
# Out:
# Query from name:  PKS J0541-0211
# No
# Query from name:  PKS J1733-3722
# No
# Query from name:  PKS J1610-3958
# No
# Query from name:  PKS J1743-0350
# RA, Dec (deg)  :  265.99523 -3.83462
# Redshift :  1.054
# Velocity :  315981.0
# Angular-diameter distance :  1717.70727627639  Mpc
# Angular radius for 1.0 Mpc seen from distance 1717.70727627639 Mpc :  0.03335596251142797  deg
# Searching objects in cone section...
# theta = 0.03335596251142797 deg; v = [314981.0, 316981.0]
# Query from name:  PKS J2253+1608
# RA, Dec (deg)  :  343.49062 16.14821
# Redshift :  0.859
# Velocity :  257522.0
# Angular-diameter distance :  1629.9307676687627  Mpc
# Angular radius for 1.0 Mpc seen from distance 1629.9307676687627 Mpc :  0.035152278028980716  deg
# Searching objects in cone section...
# theta = 0.035152278028980716 deg; v = [256522.0, 258522.0]
# Query from name:  PKS J1851+0035
# No
# Query from name:  PKS J0541-0541
# RA, Dec (deg)  :  85.40868 -5.69706
# Redshift :  0.839
# Velocity :  251526.0
# Angular-diameter distance :  1618.0605034352159  Mpc
# Angular radius for 1.0 Mpc seen from distance 1618.0605034352159 Mpc :  0.03541015888555513  deg
# Searching objects in cone section...
# theta = 0.03541015888555513 deg; v = [250526.0, 252526.0]
# Query from name:  PKS J0601-7036
# No
# Query from name:  PKS J1130-1449
# RA, Dec (deg)  :  172.52939 -14.82427
# Redshift :  1.184
# Velocity :  354954.0
# Angular-diameter distance :  1753.737300779338  Mpc
# Angular radius for 1.0 Mpc seen from distance 1753.737300779338 Mpc :  0.03267067393025217  deg
# Searching objects in cone section...
# theta = 0.03267067393025217 deg; v = [353954.0, 355954.0]
# Query from name:  PKS J1305-4928
# RA, Dec (deg)  :  196.36449 -49.46821
# Redshift :  0.001878
# Velocity :  563.0
# Angular-diameter distance :  8.292149410020395  Mpc
# Angular radius for 1.0 Mpc seen from distance 8.292149410020395 Mpc :  6.909641478944529  deg
# Searching objects in cone section...
# theta = 6.909641478944529 deg; v = [-437.0, 1563.0]
# No
# Query from name:  PKS J0336+3218
# No
# Query from name:  PKS J0006-0623
# RA, Dec (deg)  :  1.55789 -6.39315
# Redshift :  0.346676
# Velocity :  103931.0
# Angular-diameter distance :  1044.0300496957655  Mpc
# Angular radius for 1.0 Mpc seen from distance 1044.0300496957655 Mpc :  0.054879435251675504  deg
# Searching objects in cone section...
# theta = 0.054879435251675504 deg; v = [102931.0, 104931.0]
# Query from name:  PKS J1717-3342
# No
# Query from name:  PKS J1833-210B
# No
# Query from name:  PKS J0237+2848
# No
# Query from name:  PKS J0750+1231
# RA, Dec (deg)  :  117.71686 12.51801
# Redshift :  0.889
# Velocity :  266516.0
# Angular-diameter distance :  1646.623423400248  Mpc
# Angular radius for 1.0 Mpc seen from distance 1646.623423400248 Mpc :  0.03479592158039849  deg
# Searching objects in cone section...
# theta = 0.03479592158039849 deg; v = [265516.0, 267516.0]
# Query from name:  PKS J1751+0939
# RA, Dec (deg)  :  267.88674 9.6502
# Redshift :  0.322
# Velocity :  96533.0
# Angular-diameter distance :  994.3201278022433  Mpc
# Angular radius for 1.0 Mpc seen from distance 994.3201278022433 Mpc :  0.05762307119310138  deg
# Searching objects in cone section...
# theta = 0.05762307119310138 deg; v = [95533.0, 97533.0]
# Query from name:  PKS J0948+0022
# No
# Query from name:  PKS J1107-4449
# RA, Dec (deg)  :  166.78622 -44.81877
# Redshift :  1.598
# Velocity :  479068.0
# Angular-diameter distance :  1793.3027653878596  Mpc
# Angular radius for 1.0 Mpc seen from distance 1793.3027653878596 Mpc :  0.03194986402683111  deg
# Searching objects in cone section...
# theta = 0.03194986402683111 deg; v = [478068.0, 480068.0]
# Query from name:  PKS J1256-0547
# RA, Dec (deg)  :  194.04653 -5.78931
# Redshift :  0.5362
# Velocity :  160749.0
# Angular-diameter distance :  1344.817110605312  Mpc
# Angular radius for 1.0 Mpc seen from distance 1344.817110605312 Mpc :  0.04260488586979167  deg
# Searching objects in cone section...
# theta = 0.04260488586979167 deg; v = [159749.0, 161749.0]
# Query from name:  PKS J1830+0619
# No
# Query from name:  PKS J1225+1253
# RA, Dec (deg)  :  186.2656 12.88698
# Redshift :  0.003392
# Velocity :  1017.0
# Angular-diameter distance :  14.949233862918131  Mpc
# Angular radius for 1.0 Mpc seen from distance 14.949233862918131 Mpc :  3.832690025353448  deg
# Searching objects in cone section...
# theta = 3.832690025353448 deg; v = [17.0, 2017.0]
# No

# %%
ga.conedv_byname("PKS J0334-4008", 1., 1000., show=True, savefig=True, imgname="PKSJ0334-4008_env.png")
ga.cone_byname("PKS J0334-4008", 0.008, show=True, savefig=True, imgname="PKSJ0334-4008_cone.png")
# Out:
# Query from name:  PKS J0334-4008
# RA, Dec (deg)  :  53.55689 -40.14039
# Redshift :  1.445
# Velocity :  433200.0
# Angular-diameter distance :  1788.93008818  Mpc
# Angular radius for 1.0 Mpc seen from distance 1788.93008818 Mpc :  0.0320279589971  deg
# Searching objects in cone section...
# theta = 0.0320279589971 deg; v = [432200.0, 434200.0]
# Query from name:  PKS J0334-4008
# RA, Dec (deg)  :  53.55689 -40.14039
# Searching objects in cone (only)..
# theta = 0.008 deg
# <Table masked=True length=3>
#  No.          Object Name          ... Diameter Points Associations
#                                    ...
# int32            str30             ...      int32         int32
# ----- ---------------------------- ... --------------- ------------
#     1 GALEXASC J033412.25-400804.8 ...               0            0
#     2              [HB89] 0332-403 ...               0            0
#     3              MRSS 301-045883 ...               0            0

# %%
ga.conedv_byname("PKS J0423-0120", 1., 1000., show=True, savefig=True, imgname="PKS J0423-0120_env.png")
# Out:
# Query from name:  PKS J0423-0120
# RA, Dec (deg)  :  65.81584 -1.34252
# Redshift :  0.916087
# Velocity :  274636.0
# Angular-diameter distance :  1660.60635858  Mpc
# Angular radius for 1.0 Mpc seen from distance 1660.60635858 Mpc :  0.0345029267273  deg
# Searching objects in cone section...
# theta = 0.0345029267273 deg; v = [273636.0, 275636.0]
# <Table masked=True length=1>
#  No.    Object Name        RA(deg)       ... Diameter Points Associations
#                            degrees       ...
# int32      str30           float64       ...      int32         int32
# ----- --------------- ------------------ ... --------------- ------------
#    25 [HB89] 0420-014 65.815839999999994 ...               0            0

# %%
ga.conedv_byname("NGC 1052", 0.2, 500., show=True, savefig=True, imgname="NGC1052.png")
# Out:
# Query from name:  NGC 1052
# RA, Dec (deg)  :  40.26999 -8.25576
# Redshift :  0.005037
# Velocity :  1510.0
# Angular-diameter distance :  22.1542784031  Mpc
# Angular radius for 0.2 Mpc seen from distance 22.1542784031 Mpc :  0.517243472982  deg
# Searching objects in cone section...
# theta = 0.517243472982 deg; v = [1010.0, 2010.0]
# <Table masked=True length=28>
#  No.        Object Name        ... Diameter Points Associations
#                                ...
# int32          str30           ...      int32         int32
# ----- ------------------------ ... --------------- ------------
#   716                 NGC 1035 ...               9            0
#   741              2MFGC 02101 ...               0            0
#   752                HDCE 0160 ...               0            0
#  3641                 NGC 1042 ...              15            0
#  4230                 NGC 1047 ...              14            0
#  5867 SDSS J024059.55-081845.1 ...               4            0
#  5974  NGC 1052:[PBF2005] GC29 ...               0            0
#  5983 SDSS J024101.13-081650.4 ...               4            0
#  5998  NGC 1052:[PBF2005] GC37 ...               0            0
#   ...                      ... ...             ...          ...
#  6376  NGC 1052:[PBF2005] GC74 ...               0            0
#  6378  CXO J024105.71-081455.1 ...               0            1
#  6439  NGC 1052:[PBF2005] GC12 ...               0            0
#  6470 SDSS J024106.82-081347.6 ...               4            0
#  6694           NGC 0988 GROUP ...               0            0
#  7625                LDCE 0182 ...               0            0
#  7795             LEDA 3097911 ...               0            0
#  8396  2MASX J02413514-0810243 ...               6            0
#  9333 SDSS J024149.95-075530.0 ...              10            0
#  9834           [TSK2008] 0889 ...               0            0

# %%
ga.cone_byname("NGC 1052", 0.2, show=True, savefig=True, imgname="NGC1052_cone.png")
# Out:
# Query from name:  NGC 1052
# RA, Dec (deg)  :  40.26999 -8.25576
# Searching objects in cone (only)..
# theta = 0.2 deg
# <Table masked=True length=2011>
#  No.          Object Name          ... Diameter Points Associations
#                                    ...
# int32            str30             ...      int32         int32
# ----- ---------------------------- ... --------------- ------------
#     1     SDSS J024017.17-081441.3 ...               4            1
#     2        2XMM J024017.2-081434 ...               0            1
#     3     SDSS J024017.63-081256.3 ...               4            0
#     4 GALEXMSC J024017.82-081517.3 ...               0            0
#     5     SDSS J024018.24-081723.6 ...               4            0
#     6     SDSS J024018.49-081219.0 ...               4            0
#     7     SDSS J024018.63-081257.2 ...               4            0
#     8     SDSS J024018.88-081855.0 ...               3            0
#     9 GALEXMSC J024018.98-081532.9 ...               0            0
#   ...                          ... ...             ...          ...
#  2002     SDSS J024151.32-081413.3 ...               4            0
#  2003     SDSS J024151.50-081545.7 ...               3            0
#  2004     SDSS J024151.63-081718.0 ...               4            0
#  2005     SDSS J024151.63-081417.1 ...               3            0
#  2006 GALEXMSC J024151.80-081352.3 ...               0            0
#  2007 GALEXMSC J024152.17-081410.6 ...               0            0
#  2008     SDSS J024152.41-081519.0 ...               4            0
#  2009     SDSS J024152.48-081516.3 ...               4            0
#  2010     SDSS J024152.72-081349.0 ...               4            0
#  2011     SDSS J024153.29-081518.2 ...               4            0
