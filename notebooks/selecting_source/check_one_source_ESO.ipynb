# %%
from astroquery.alma import Alma
from astropy import coordinates
from astropy import units as u

import numpy as np
import pandas as pd

# %%
def query_object(obj, theta = 0.005, science = False, public = True, savedb=False, dbname='calibrators.db'):
    """
    query per object
    obj is an array consist of at least [objname, ra, dec, ...]
    ra and dec are in degrees
    """

    region = coordinates.SkyCoord(obj[1], obj[2], unit='deg')

    alma_data = Alma.query_region(region, theta*u.deg, science = science, public = public)
    # it is in astropy Table format

    df = alma_data.to_pandas() # convert to pandas Dataframe

    #! change Numpy Masked-Array to str, so it can be converted to SQL
    #df['Band'] = df['Band'].astype("str")

    # save the query result in sql database 
    # with Table's name = calibrator's name
    if savedb:
        conn = sql.connect(dbname)
        conn.text_factory = str
        if not df.dropna().empty:
            df.to_sql(obj[0], conn, if_exists='replace') # if the Table exist in the db, just replace it


    return alma_data, df

# %%
# from astropy.coordinates import SkyCoord
# c = SkyCoord('11h39m10.7025s', '-13d50m43.639s', frame='icrs')
# c

# %%
#obj = ["J1833-210B", 278.41633, -21.06108]
#obj = ["J1139-1350", 174.79459375, -13.84545528]
#obj = ['J0541-0211', 85.340401, -2.185662]
obj = ["J0501-0159", 75.3031, -1.98746]

# %%
table, df = query_object(obj)

# %%
df
# Out:
#          Project code    Source name         RA       Dec  Galactic longitude  \
# 0   b'2012.1.00219.S'  b'J0501-0159'  75.303375 -1.987293          201.451028
# 1   b'2012.1.00239.S'  b'J0501-0159'  75.303375 -1.987293          201.451028
# 2   b'2012.1.01099.S'  b'J0501-0159'  75.303375 -1.987293          201.451028
# 3   b'2013.1.00991.S'  b'J0501-0159'  75.303375 -1.987293          201.451028
# 4   b'2013.1.01241.S'  b'J0501-0159'  75.303375 -1.987293          201.451028
# 5   b'2013.1.00989.S'  b'J0501-0159'  75.303375 -1.987293          201.451028
# 6   b'2013.1.00662.S'  b'J0501-0159'  75.303375 -1.987293          201.451028
# 7   b'2013.1.00662.S'  b'J0501-0159'  75.303375 -1.987293          201.451028
# 8   b'2013.1.00553.S'  b'J0501-0159'  75.303375 -1.987293          201.451028
# 9   b'2015.1.01558.T'  b'J0501-0159'  75.303375 -1.987293          201.451028
# 10  b'2013.1.00048.S'  b'J0501-0159'  75.303375 -1.987293          201.451028
# 11  b'2013.1.00662.S'  b'J0501-0159'  75.303375 -1.987293          201.451028
# 12  b'2013.1.00662.S'  b'J0501-0159'  75.303375 -1.987293          201.451028
# 13  b'2013.1.01172.S'  b'J0501-0159'  75.303375 -1.987293          201.451028
# 14  b'2013.1.00231.S'  b'J0501-0159'  75.303375 -1.987293          201.451028
# 15  b'2013.1.00231.S'  b'J0501-0159'  75.303375 -1.987293          201.451028
# 16  b'2015.1.00187.S'  b'J0501-0159'  75.303375 -1.987293          201.451028
# 17  b'2015.1.00192.S'  b'J0501-0159'  75.303375 -1.987293          201.451028
# 18  b'2016.1.00376.S'  b'J0501-0159'  75.303375 -1.987293          201.451028
# 19  b'2016.1.00683.S'  b'J0501-0159'  75.303375 -1.987293          201.451028
# 20  b'2016.1.01082.S'  b'J0501-0159'  75.303375 -1.987293          201.451028
# 21  b'2016.2.00006.S'  b'J0501-0159'  75.303375 -1.987293          201.451028
# 22  b'2016.1.00209.S'  b'J0501-0159'  75.303375 -1.987293          201.451028
#
#     Galactic latitude Band  Spatial resolution  Frequency resolution  \
# 0          -25.295595  [3]            1.348574            976.562500
# 1          -25.295595  [6]            4.767373            976.562500
# 2          -25.295595  [3]            8.757429          31250.000000
# 3          -25.295595  [3]            2.290930           3906.250000
# 4          -25.295595  [6]            0.957684           1953.125000
# 5          -25.295595  [7]            0.850650          31250.000000
# 6          -25.295595  [3]            2.880367             61.035156
# 7          -25.295595  [3]            3.016803             61.035156
# 8          -25.295595  [6]            1.209399            976.562500
# 9          -25.295594  [7]            0.016120          31250.000000
# 10         -25.295595  [8]            0.080704            976.562500
# 11         -25.295594  [3]            8.452530             61.035156
# 12         -25.295595  [3]           13.681222             61.035156
# 13         -25.295595  [3]            2.359593           1953.125000
# 14         -25.295595  [7]            0.953308          62500.000000
# 15         -25.295595  [7]            0.881671          62500.000000
# 16         -25.295594  [6]            0.862255            976.562500
# 17         -25.295594  [6]            0.239247            122.070312
# 18         -25.295594  [6]            0.266693            244.140625
# 19         -25.295594  [6]            0.466657           1953.125000
# 20         -25.295594  [6]            5.463150            122.070312
# 21         -25.295594  [3]           11.750109            976.562500
# 22         -25.295594  [6]            7.531851             30.517578
#
#        Array        ...          \
# 0     b'12m'        ...
# 1      b'7m'        ...
# 2   b'12m7m'        ...
# 3     b'12m'        ...
# 4     b'12m'        ...
# 5     b'12m'        ...
# 6     b'12m'        ...
# 7     b'12m'        ...
# 8     b'12m'        ...
# 9     b'12m'        ...
# 10    b'12m'        ...
# 11     b'7m'        ...
# 12     b'7m'        ...
# 13  b'12m7m'        ...
# 14    b'12m'        ...
# 15    b'12m'        ...
# 16    b'12m'        ...
# 17    b'12m'        ...
# 18    b'12m'        ...
# 19    b'12m'        ...
# 20     b'7m'        ...
# 21     b'7m'        ...
# 22     b'7m'        ...
#
#                                         Project title  Project type  \
# 0   b'Spectroscopy of a normal star forming galaxy...          b'S'
# 1   b'Probing a mass distribution of the central 1...          b'S'
# 2    b'The Crab nebula at 100GHz: filling in the gap'          b'S'
# 3               b'The full anatomy of a minor merger'          b'S'
# 4   b'Detecting [CII] in two strongly lensed z~6 s...          b'S'
# 5   b'Probing the inner-most region of the relativ...          b'S'
# 6                              b'Orion 2 & 3 mapping'          b'S'
# 7                              b'Orion 2 & 3 mapping'          b'S'
# 8                        b'Molecular oxygen in Orion'          b'S'
# 9          b'Particle Acceleration in GRB Afterglows'          b'T'
# 10  b'Physical properties of an accretion disk aro...          b'S'
# 11                             b'Orion 2 & 3 mapping'          b'S'
# 12                             b'Orion 2 & 3 mapping'          b'S'
# 13  b'CO isotopic ratio enhancement of Pa alpha-se...          b'S'
# 14  b'Revealing Magnetic Field Structures: Interme...          b'S'
# 15  b'Revealing Magnetic Field Structures: Interme...          b'S'
# 16                b'Gas in the most MASSIVE Galaxies'          b'S'
# 17                 b'Hunting for gaps in HEABE disks'          b'S'
# 18  b'Surveying the chemical nature of protostars ...          b'S'
# 19  b'Black hole mass measurements in the most MAS...          b'S'
# 20  b'To what extent is the protostellar outflow H...          b'S'
# 21  b'Recovering Extended Structures in Merger Rem...          b'S'
# 22  b'Multi-scale disk and envelope kinematics aro...          b'S'
#
#         Scan intent Field of view  Largest angular scale QA2 Status COUNT  \
# 0      b'PHASE WVR'     58.383127              10.860459       b'Y'   0.0
# 1       b'BANDPASS'     25.127508              20.085598       b'Y'   1.0
# 2   b'BANDPASS WVR'     63.003418              36.143275       b'Y'   1.0
# 3   b'BANDPASS WVR'     59.145019              13.472503       b'Y'   2.0
# 4      b'PHASE WVR'     24.639672               5.602774       b'Y'   1.0
# 5   b'BANDPASS WVR'     18.340901               4.185990       b'Y'   1.0
# 6   b'BANDPASS WVR'     68.548580              14.029071       b'Y'   0.0
# 7   b'BANDPASS WVR'     68.548335              15.052100       b'Y'   0.0
# 8   b'BANDPASS WVR'     27.686461               5.954154       b'Y'   2.0
# 9      b'PHASE WVR'     18.340901               0.115197       b'Y'   0.0
# 10     b'PHASE WVR'     14.523808               0.425156       b'Y'   3.0
# 11  b'BANDPASS WVR'     68.545376              54.767834       b'Y'   0.0
# 12      b'BANDPASS'     68.543811              50.608697       b'Y'   0.0
# 13  b'BANDPASS WVR'     61.994044              12.637058       b'Y'   4.0
# 14  b'BANDPASS WVR'     18.340901               4.700671       b'Y'   0.0
# 15  b'BANDPASS WVR'     18.340901               4.347928       b'Y'   0.0
# 16     b'PHASE WVR'     26.780126               4.031615       b'Y'   0.0
# 17     b'PHASE WVR'     27.929815               1.203499       b'Y'   1.0
# 18     b'PHASE WVR'     24.921404               1.264530       b'Y'   0.0
# 19     b'PHASE WVR'     26.777859               2.284317       b'Y'   1.0
# 20     b'PHASE WVR'     27.876625              22.429416       b'Y'   0.0
# 21     b'PHASE WVR'     60.584694              43.350269       b'Y'   0.0
# 22     b'PHASE WVR'     28.060888              22.577690       b'Y'   0.0
#
#                                       Science keyword  \
# 0   b'Gravitational lenses, Galaxy structure & evo...
# 1                          b'Low-mass star formation'
# 2                        b'Pulsars and neutron stars'
# 3                 b'Merging and interacting galaxies'
# 4   b'Lyman Break Galaxies (LBG), Gravitational le...
# 5       b'Active Galactic Nuclei (AGN)/Quasars (QSO)'
# 6   b'High-mass star formation, Pre-stellar cores,...
# 7   b'High-mass star formation, Pre-stellar cores,...
# 8   b'Astrochemistry, Inter-Stellar Medium (ISM)/M...
# 9                           b'Gamma Ray Bursts (GRB)'
# 10                        b'High-mass star formation'
# 11  b'High-mass star formation, Pre-stellar cores,...
# 12  b'High-mass star formation, Pre-stellar cores,...
# 13  b'Merging and interacting galaxies, Surveys of...
# 14                b'Intermediate-mass star formation'
# 15                b'Intermediate-mass star formation'
# 16    b'Early-type galaxies, Galactic centres/nuclei'
# 17                    b'Disks around high-mass stars'
# 18                                  b'Astrochemistry'
# 19    b'Early-type galaxies, Galactic centres/nuclei'
# 20  b'Outflows, jets and ionized winds, Low-mass s...
# 21                b'Merging and interacting galaxies'
# 22                         b'Low-mass star formation'
#
#                Scientific category   ASA_PROJECT_CODE
# 0                     b'Cosmology'  b'2012.1.00219.S'
# 1        b'ISM and star formation'  b'2012.1.00239.S'
# 2   b'Stars and stellar evolution'  b'2012.1.01099.S'
# 3              b'Galaxy evolution'  b'2013.1.00991.S'
# 4              b'Galaxy evolution'  b'2013.1.01241.S'
# 5               b'Active galaxies'  b'2013.1.00989.S'
# 6        b'ISM and star formation'  b'2013.1.00662.S'
# 7        b'ISM and star formation'  b'2013.1.00662.S'
# 8        b'ISM and star formation'  b'2013.1.00553.S'
# 9                     b'Cosmology'  b'2015.1.01558.T'
# 10       b'ISM and star formation'  b'2013.1.00048.S'
# 11       b'ISM and star formation'  b'2013.1.00662.S'
# 12       b'ISM and star formation'  b'2013.1.00662.S'
# 13             b'Galaxy evolution'  b'2013.1.01172.S'
# 14       b'ISM and star formation'  b'2013.1.00231.S'
# 15       b'ISM and star formation'  b'2013.1.00231.S'
# 16             b'Galaxy evolution'  b'2015.1.00187.S'
# 17   b'Disks and planet formation'  b'2015.1.00192.S'
# 18       b'ISM and star formation'  b'2016.1.00376.S'
# 19             b'Galaxy evolution'  b'2016.1.00683.S'
# 20       b'ISM and star formation'  b'2016.1.01082.S'
# 21             b'Galaxy evolution'  b'2016.2.00006.S'
# 22       b'ISM and star formation'  b'2016.1.00209.S'
#
# [23 rows x 36 columns]

# %%
table
# Out:
# <Table masked=True length=23>
#  Project code  Source name ...     Scientific category     ASA_PROJECT_CODE
#                            ...
#    bytes64       bytes256  ...           bytes200              bytes64
# -------------- ----------- ... --------------------------- ----------------
# 2012.1.00219.S  J0501-0159 ...                   Cosmology   2012.1.00219.S
# 2012.1.00239.S  J0501-0159 ...      ISM and star formation   2012.1.00239.S
# 2012.1.01099.S  J0501-0159 ... Stars and stellar evolution   2012.1.01099.S
# 2013.1.00991.S  J0501-0159 ...            Galaxy evolution   2013.1.00991.S
# 2013.1.01241.S  J0501-0159 ...            Galaxy evolution   2013.1.01241.S
# 2013.1.00989.S  J0501-0159 ...             Active galaxies   2013.1.00989.S
# 2013.1.00662.S  J0501-0159 ...      ISM and star formation   2013.1.00662.S
# 2013.1.00662.S  J0501-0159 ...      ISM and star formation   2013.1.00662.S
# 2013.1.00553.S  J0501-0159 ...      ISM and star formation   2013.1.00553.S
#            ...         ... ...                         ...              ...
# 2013.1.01172.S  J0501-0159 ...            Galaxy evolution   2013.1.01172.S
# 2013.1.00231.S  J0501-0159 ...      ISM and star formation   2013.1.00231.S
# 2013.1.00231.S  J0501-0159 ...      ISM and star formation   2013.1.00231.S
# 2015.1.00187.S  J0501-0159 ...            Galaxy evolution   2015.1.00187.S
# 2015.1.00192.S  J0501-0159 ...  Disks and planet formation   2015.1.00192.S
# 2016.1.00376.S  J0501-0159 ...      ISM and star formation   2016.1.00376.S
# 2016.1.00683.S  J0501-0159 ...            Galaxy evolution   2016.1.00683.S
# 2016.1.01082.S  J0501-0159 ...      ISM and star formation   2016.1.01082.S
# 2016.2.00006.S  J0501-0159 ...            Galaxy evolution   2016.2.00006.S
# 2016.1.00209.S  J0501-0159 ...      ISM and star formation   2016.1.00209.S

# %%
proj3 = []
proj4 = []
proj6 = []
proj7 = []
proj8 = []
proj9 = []
projelse = []
for i, p, in enumerate(table['Project code']):
    if table['Band'][i][0] == 3:
        proj3.append([p, table['Band'][i][0], table['Integration'][i]])
    elif table['Band'][i][0] == 4:
        proj4.append([p, table['Band'][i][0], table['Integration'][i]])
    elif table['Band'][i][0] == 6:
        proj6.append([p, table['Band'][i][0], table['Integration'][i]])
    elif table['Band'][i][0] == 7:
        proj7.append([p, table['Band'][i][0], table['Integration'][i]])
    elif table['Band'][i][0] == 8:
        proj8.append([p, table['Band'][i][0], table['Integration'][i]])
    elif table['Band'][i][0] == 9:
        proj9.append([p, table['Band'][i][0], table['Integration'][i]])
    else:
        projelse.append([p, table['Band'][i][0], table['Integration'][i]])

# %%
print("Band3:")
for i in proj3:
    print(i)

print("Band4:")
for i in proj4:
    print(i)
    
print("Band6:")
for i in proj6:
    print(i)

print("Band7:")
for i in proj7:
    print(i)

print("Band8:")
for i in proj8:
    print(i)

print("Band9:")
for i in proj9:
    print(i)

print("Else:")
for i in projelse:
    print(i)
# Out:
# Band3:
# ['2012.1.00219.S', 3, 937.44]
# ['2012.1.01099.S', 3, 604.8]
# ['2013.1.00991.S', 3, 302.4]
# ['2013.1.00662.S', 3, 302.4]
# ['2013.1.00662.S', 3, 604.8]
# ['2013.1.00662.S', 3, 6048.0]
# ['2013.1.00662.S', 3, 604.8]
# ['2013.1.01172.S', 3, 302.4]
# ['2016.2.00006.S', 3, 302.4]
# Band4:
# Band6:
# ['2012.1.00239.S', 6, 604.8]
# ['2013.1.01241.S', 6, 635.04]
# ['2013.1.00553.S', 6, 302.4]
# ['2015.1.00187.S', 6, 90.72]
# ['2015.1.00192.S', 6, 151.2]
# ['2016.1.00376.S', 6, 272.16]
# ['2016.1.00683.S', 6, 60.48]
# ['2016.1.01082.S', 6, 1935.36]
# ['2016.1.00209.S', 6, 241.92]
# Band7:
# ['2013.1.00989.S', 7, 302.4]
# ['2015.1.01558.T', 7, 181.44]
# ['2013.1.00231.S', 7, 302.4]
# ['2013.1.00231.S', 7, 302.4]
# Band8:
# ['2013.1.00048.S', 8, 423.36]
# Band9:
# Else:

# %%
projs = [proj3, proj4, proj6, proj7, proj8, proj9, projelse]
bname = ['3', '4', '6', '7', '8', '9', 'else']

# %%
for i, arr in enumerate(projs):
    pband = []
    for p in arr:
        pband.append(p[0])
    setpband = set(pband)
    print("'''Band "+bname[i]+"''':\n")
    for p in setpband:
        print("[["+p+"]]\n")
    print("\n")
# Out:
# '''Band 3''':
#
# [[2013.1.00991.S]]
#
# [[2013.1.00662.S]]
#
# [[2012.1.00219.S]]
#
# [[2016.2.00006.S]]
#
# [[2013.1.01172.S]]
#
# [[2012.1.01099.S]]
#
#
#
# '''Band 4''':
#
#
#
# '''Band 6''':
#
# [[2015.1.00192.S]]
#
# [[2013.1.00553.S]]
#
# [[2016.1.01082.S]]
#
# [[2016.1.00209.S]]
#
# [[2016.1.00376.S]]
#
# [[2012.1.00239.S]]
#
# [[2016.1.00683.S]]
#
# [[2013.1.01241.S]]
#
# [[2015.1.00187.S]]
#
#
#
# '''Band 7''':
#
# [[2015.1.01558.T]]
#
# [[2013.1.00989.S]]
#
# [[2013.1.00231.S]]
#
#
#
# '''Band 8''':
#
# [[2013.1.00048.S]]
#
#
#
# '''Band 9''':
#
#
#
# '''Band else''':
